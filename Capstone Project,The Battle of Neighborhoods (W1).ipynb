# %% [markdown]
# Capstone Project - The Battle of Neighborhoods (Week 1)

# %% [markdown]
# Problem Statement
#
#     What is / are the best location(s) for Japanese cuisine in New York City?
#     In what Neighborhood and/or borough should the investor open a Japanese restaurant to have the best chance of being successful?
#     Where would I go in New York City to have the best Japanese food?

# %% [markdown]
# Required libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import requests # library to handle requests

#from bs4 import BeautifulSoup
import os

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # map rendering library

#!conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import requests # library to handle requests

# Matplotlib and associated plotting modules
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline

import seaborn as sns

print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python-3.7-main
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |           1_llvm           5 KB  conda-forge
#     _py-xgboost-mutex-2.0      |            cpu_0           8 KB  conda-forge
#     _pytorch_select-0.2        |            gpu_0           2 KB
#     absl-py-0.13.0             |     pyhd8ed1ab_0          97 KB  conda-forge
#     aiohttp-3.7.4.post0        |   py37h5e8e339_0         625 KB  conda-forge
#     alsa-lib-1.2.3             |       h516909a_0         560 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     appdirs-1.4.4              |     pyh9f0ad1d_0          13 KB  conda-forge
#     argon2-cffi-20.1.0         |   py37h5e8e339_2          47 KB  conda-forge
#     astor-0.8.1                |     pyh9f0ad1d_0          25 KB  conda-forge
#     astropy-4.2.1              |   py37h5e8e339_0         7.5 MB  conda-forge
#     async-timeout-3.0.1        |          py_1000          11 KB  conda-forge
#     async_generator-1.10       |             py_0          18 KB  conda-forge
#     attrs-21.2.0               |     pyhd8ed1ab_0          44 KB  conda-forge
#     backcall-0.2.0             |     pyh9f0ad1d_0          13 KB  conda-forge
#     backports-1.0              |             py_2           4 KB  conda-forge
#     backports.functools_lru_cache-1.6.4|     pyhd8ed1ab_0           9 KB  conda-forge
#     beautifulsoup4-4.9.3       |     pyhb0f4dca_0          86 KB  conda-forge
#     biopython-1.79             |   py37h5e8e339_0         2.6 MB  conda-forge
#     blas-1.0                   |              mkl           1 KB  conda-forge
#     bleach-3.3.0               |     pyh44b312d_0         111 KB  conda-forge
#     blinker-1.4                |             py_1          13 KB  conda-forge
#     blosc-1.21.0               |       h9c3ff4c_0         841 KB  conda-forge
#     bokeh-2.3.2                |   py37h89c1867_0         8.3 MB  conda-forge
#     boto3-1.17.105             |     pyhd8ed1ab_0          70 KB  conda-forge
#     botocore-1.20.105          |     pyhd8ed1ab_0         4.7 MB  conda-forge
#     branca-0.4.2               |     pyhd8ed1ab_0          26 KB  conda-forge
#     brotli-1.0.9               |       h7f98852_5          17 KB  conda-forge
#     brotli-bin-1.0.9           |       h7f98852_5          19 KB  conda-forge
#     brotlipy-0.7.0             |py37h5e8e339_1001         341 KB  conda-forge
#     brunsli-0.1                |       h9c3ff4c_0         200 KB  conda-forge
#     bzip2-1.0.8                |       h7f98852_4         484 KB  conda-forge
#     c-ares-1.17.1              |       h7f98852_1         109 KB  conda-forge
#     ca-certificates-2021.5.30  |       ha878542_0         136 KB  conda-forge
#     cached-property-1.5.2      |       hd8ed1ab_1           4 KB  conda-forge
#     cached_property-1.5.2      |     pyha770c72_1          11 KB  conda-forge
#     cachetools-4.2.2           |     pyhd8ed1ab_0          12 KB  conda-forge
#     certifi-2021.5.30          |   py37h89c1867_0         141 KB  conda-forge
#     cffi-1.14.5                |   py37hc58025e_0         225 KB  conda-forge
#     cfitsio-3.470              |       h2e3daa1_7         1.3 MB  conda-forge
#     chardet-4.0.0              |   py37h89c1867_1         204 KB  conda-forge
#     charls-2.2.0               |       h9c3ff4c_0         138 KB  conda-forge
#     click-8.0.1                |   py37h89c1867_0         145 KB  conda-forge
#     cloudpickle-1.6.0          |             py_0          22 KB  conda-forge
#     cryptography-3.4.7         |   py37h5d9358c_0         1.1 MB  conda-forge
#     cx_oracle-8.2.1            |   py37h5e8e339_0         199 KB  conda-forge
#     cycler-0.10.0              |             py_2           9 KB  conda-forge
#     cytoolz-0.11.0             |   py37h5e8e339_3         403 KB  conda-forge
#     dask-core-2021.6.2         |     pyhd8ed1ab_0         743 KB  conda-forge
#     dataclasses-0.8            |     pyhc8e2a94_1           7 KB  conda-forge
#     dbus-1.13.6                |       h48d8840_2         572 KB  conda-forge
#     decorator-5.0.9            |     pyhd8ed1ab_0          11 KB  conda-forge
#     defusedxml-0.7.1           |     pyhd8ed1ab_0          23 KB  conda-forge
#     dill-0.3.4                 |     pyhd8ed1ab_0          62 KB  conda-forge
#     docutils-0.17.1            |   py37h89c1867_0         762 KB  conda-forge
#     entrypoints-0.3            |  pyhd8ed1ab_1003           8 KB  conda-forge
#     expat-2.4.1                |       h9c3ff4c_0         182 KB  conda-forge
#     fastcache-1.1.0            |   py37h5e8e339_2          30 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     fontconfig-2.13.1          |    hba837de_1005         357 KB  conda-forge
#     freetds-1.1.15             |       h94af77a_0         2.5 MB  conda-forge
#     freetype-2.10.4            |       h0708190_1         890 KB  conda-forge
#     fsspec-2021.6.1            |     pyhd8ed1ab_0          79 KB  conda-forge
#     future-0.18.2              |   py37h89c1867_3         714 KB  conda-forge
#     gast-0.5.0                 |     pyhd8ed1ab_0          12 KB  conda-forge
#     gettext-0.19.8.1           |    h0b5b191_1005         3.6 MB  conda-forge
#     giflib-5.2.1               |       h36c2ea0_2          77 KB  conda-forge
#     glib-2.68.3                |       h9c3ff4c_0         449 KB  conda-forge
#     glib-tools-2.68.3          |       h9c3ff4c_0          86 KB  conda-forge
#     gmp-6.2.1                  |       h58526e2_0         806 KB  conda-forge
#     gmpy2-2.1.0b5              |   py37h025e8b9_0         207 KB  conda-forge
#     google-auth-1.32.1         |     pyh6c4a22f_0          78 KB  conda-forge
#     google-auth-oauthlib-0.4.4 |     pyhd8ed1ab_0          19 KB  conda-forge
#     google-pasta-0.2.0         |     pyh8c360ce_0          42 KB  conda-forge
#     greenlet-1.1.0             |   py37hcd2ae1e_0          83 KB  conda-forge
#     grpcio-1.38.1              |   py37hb27c1af_0         2.2 MB  conda-forge
#     gst-plugins-base-1.18.4    |       hf529b03_2         2.6 MB  conda-forge
#     gstreamer-1.18.4           |       h76c114f_2         2.0 MB  conda-forge
#     h5py-3.3.0                 |nompi_py37ha3df211_100         1.3 MB  conda-forge
#     hdf5-1.10.6                |nompi_h7c3c948_1111         3.1 MB  conda-forge
#     html5lib-1.1               |     pyh9f0ad1d_0          89 KB  conda-forge
#     ibm-wsrt-py37main-keep-0.0.0|             2527           2 KB
#     ibm-wsrt-py37main-main-custom|             2527           2 KB
#     icu-68.1                   |       h58526e2_0        13.0 MB  conda-forge
#     idna-2.10                  |     pyh9f0ad1d_0          52 KB  conda-forge
#     imagecodecs-2021.6.8       |   py37hd3505d4_0         7.0 MB  conda-forge
#     imageio-2.9.0              |             py_0         3.1 MB  conda-forge
#     importlib-metadata-4.6.1   |   py37h89c1867_0          31 KB  conda-forge
#     importlib_metadata-4.6.1   |       hd8ed1ab_0           3 KB  conda-forge
#     iniconfig-1.1.1            |     pyh9f0ad1d_0           8 KB  conda-forge
#     ipykernel-5.5.5            |   py37h085eea5_0         167 KB  conda-forge
#     ipython-7.25.0             |   py37h085eea5_1         1.1 MB  conda-forge
#     ipython_genutils-0.2.0     |             py_1          21 KB  conda-forge
#     ipywidgets-7.6.3           |     pyhd3deb0d_0         101 KB  conda-forge
#     jbig-2.1                   |    h7f98852_2003          43 KB  conda-forge
#     jedi-0.18.0                |   py37h89c1867_2         923 KB  conda-forge
#     jeepney-0.6.0              |     pyhd8ed1ab_0          32 KB  conda-forge
#     jinja2-3.0.1               |     pyhd8ed1ab_0          99 KB  conda-forge
#     jmespath-0.10.0            |     pyh9f0ad1d_0          21 KB  conda-forge
#     joblib-1.0.1               |     pyhd8ed1ab_0         206 KB  conda-forge
#     jpeg-9d                    |       h36c2ea0_0         264 KB  conda-forge
#     json5-0.9.5                |     pyh9f0ad1d_0          20 KB  conda-forge
#     jsonschema-3.2.0           |     pyhd8ed1ab_3          45 KB  conda-forge
#     jupyter_client-6.1.12      |     pyhd8ed1ab_0          79 KB  conda-forge
#     jupyter_core-4.7.1         |   py37h89c1867_0          72 KB  conda-forge
#     jupyterlab-2.2.6           |             py_0         5.9 MB  conda-forge
#     jupyterlab_pygments-0.1.2  |     pyh9f0ad1d_0           8 KB  conda-forge
#     jupyterlab_server-1.2.0    |             py_0          25 KB  conda-forge
#     jupyterlab_widgets-1.0.0   |     pyhd8ed1ab_1         130 KB  conda-forge
#     jxrlib-1.1                 |       h7f98852_2         235 KB  conda-forge
#     keras-applications-1.0.8   |             py_1          30 KB  conda-forge
#     keras-preprocessing-1.1.2  |     pyhd8ed1ab_0          34 KB  conda-forge
#     keyring-18.0.0             |           py37_0          50 KB  conda-forge
#     kiwisolver-1.3.1           |   py37h2527ec5_1          78 KB  conda-forge
#     krb5-1.19.1                |       hcc1bbae_0         1.4 MB  conda-forge
#     lcms2-2.12                 |       hddcbb42_0         443 KB  conda-forge
#     ld_impl_linux-64-2.36.1    |       hea4e1c9_0         670 KB  conda-forge
#     lerc-2.2.1                 |       h9c3ff4c_0         213 KB  conda-forge
#     libaec-1.0.5               |       h9c3ff4c_0          46 KB  conda-forge
#     libblas-3.9.0              |            8_mkl          12 KB  conda-forge
#     libbrotlicommon-1.0.9      |       h7f98852_5          65 KB  conda-forge
#     libbrotlidec-1.0.9         |       h7f98852_5          33 KB  conda-forge
#     libbrotlienc-1.0.9         |       h7f98852_5         286 KB  conda-forge
#     libcblas-3.9.0             |            8_mkl          11 KB  conda-forge
#     libclang-11.1.0            |default_ha53f305_1        19.2 MB  conda-forge
#     libcurl-7.77.0             |       h2574ce0_0         334 KB  conda-forge
#     libdeflate-1.7             |       h7f98852_5          67 KB  conda-forge
#     libedit-3.1.20191231       |       he28a2e2_2         121 KB  conda-forge
#     libev-4.33                 |       h516909a_1         104 KB  conda-forge
#     libevent-2.1.10            |       hcdb4288_3         1.1 MB  conda-forge
#     libffi-3.3                 |       h58526e2_2          51 KB  conda-forge
#     libgcc-ng-9.3.0            |      h2828fa1_19         7.8 MB  conda-forge
#     libgfortran-ng-7.5.0       |      h14aa051_19          22 KB  conda-forge
#     libgfortran4-7.5.0         |      h14aa051_19         1.3 MB  conda-forge
#     libglib-2.68.3             |       h3e27bee_0         3.1 MB  conda-forge
#     libiconv-1.16              |       h516909a_0         1.4 MB  conda-forge
#     liblapack-3.9.0            |            8_mkl          11 KB  conda-forge
#     libllvm11-11.1.0           |       hf817b99_2        29.1 MB  conda-forge
#     libnghttp2-1.43.0          |       h812cca2_0         808 KB  conda-forge
#     libogg-1.3.4               |       h7f98852_1         206 KB  conda-forge
#     libopus-1.3.1              |       h7f98852_1         255 KB  conda-forge
#     libpng-1.6.37              |       h21135ba_2         306 KB  conda-forge
#     libpq-13.3                 |       hd57d9b9_0         2.7 MB  conda-forge
#     libprotobuf-3.17.2         |       h780b84a_0         2.5 MB  conda-forge
#     libsodium-1.0.18           |       h36c2ea0_1         366 KB  conda-forge
#     libssh2-1.9.0              |       ha56f1ee_6         226 KB  conda-forge
#     libstdcxx-ng-9.3.0         |      h6de172a_19         4.0 MB  conda-forge
#     libtiff-4.3.0              |       hf544144_1         668 KB  conda-forge
#     libuuid-2.32.1             |    h7f98852_1000          28 KB  conda-forge
#     libvorbis-1.3.7            |       h9c3ff4c_0         280 KB  conda-forge
#     libwebp-base-1.2.0         |       h7f98852_2         815 KB  conda-forge
#     libxcb-1.13                |    h7f98852_1003         395 KB  conda-forge
#     libxgboost-1.4.0           |       h9c3ff4c_0         3.3 MB  conda-forge
#     libxkbcommon-1.0.3         |       he3ba5ed_0         581 KB  conda-forge
#     libxml2-2.9.12             |       h72842e0_0         772 KB  conda-forge
#     libxslt-1.1.33             |       h15afd5d_2         522 KB  conda-forge
#     libzopfli-1.0.3            |       h9c3ff4c_0         164 KB  conda-forge
#     llvm-openmp-11.1.0         |       h4bd325d_1         4.7 MB  conda-forge
#     locket-0.2.0               |             py_2           6 KB  conda-forge
#     lxml-4.6.3                 |   py37h77fd288_0         1.5 MB  conda-forge
#     lz4-c-1.9.3                |       h9c3ff4c_0         179 KB  conda-forge
#     lzo-2.10                   |    h516909a_1000         314 KB  conda-forge
#     markdown-3.3.4             |     pyhd8ed1ab_0          67 KB  conda-forge
#     markupsafe-2.0.1           |   py37h5e8e339_0          22 KB  conda-forge
#     matplotlib-3.4.2           |   py37h89c1867_0           7 KB  conda-forge
#     matplotlib-base-3.4.2      |   py37hdd32ed1_0         7.2 MB  conda-forge
#     matplotlib-inline-0.1.2    |     pyhd8ed1ab_2          11 KB  conda-forge
#     mistune-0.8.4              |py37h5e8e339_1004          54 KB  conda-forge
#     mkl-2020.4                 |     h726a3e6_304       215.6 MB  conda-forge
#     mkl-service-2.3.0          |   py37h8f50634_2          54 KB  conda-forge
#     mkl_fft-1.3.0              |   py37h902c9e0_1         204 KB  conda-forge
#     mkl_random-1.2.0           |   py37h9fdb41a_1         313 KB  conda-forge
#     mock-4.0.3                 |   py37h89c1867_1          51 KB  conda-forge
#     more-itertools-8.8.0       |     pyhd8ed1ab_0          39 KB  conda-forge
#     mpc-1.1.0                  |    h04dde30_1009         105 KB  conda-forge
#     mpfr-4.0.2                 |       he80fd80_1         648 KB  conda-forge
#     mpmath-1.2.1               |     pyhd8ed1ab_0         437 KB  conda-forge
#     multidict-5.1.0            |   py37h5e8e339_1          67 KB  conda-forge
#     mysql-common-8.0.25        |       ha770c72_2         1.6 MB  conda-forge
#     mysql-libs-8.0.25          |       hfa10184_2         1.8 MB  conda-forge
#     nbclient-0.5.3             |     pyhd8ed1ab_0          67 KB  conda-forge
#     nbconvert-6.1.0            |   py37h89c1867_0         548 KB  conda-forge
#     nbformat-5.1.3             |     pyhd8ed1ab_0          47 KB  conda-forge
#     ncurses-6.2                |       h58526e2_4         985 KB  conda-forge
#     nest-asyncio-1.5.1         |     pyhd8ed1ab_0           9 KB  conda-forge
#     networkx-2.5               |             py_0         1.2 MB  conda-forge
#     ninja-1.10.2               |       h4bd325d_0         2.4 MB  conda-forge
#     nltk-3.6.2                 |     pyhd8ed1ab_0         1.1 MB  conda-forge
#     notebook-6.4.0             |     pyha770c72_0         6.1 MB  conda-forge
#     nspr-4.30                  |       h9c3ff4c_0         233 KB  conda-forge
#     nss-3.67                   |       hb5efdd6_0         2.1 MB  conda-forge
#     numexpr-2.7.3              |   py37hdc94413_0         201 KB  conda-forge
#     numpy-1.20.3               |   py37h038b26d_0         5.7 MB  conda-forge
#     oauthlib-3.1.1             |     pyhd8ed1ab_0          87 KB  conda-forge
#     olefile-0.46               |     pyh9f0ad1d_1          32 KB  conda-forge
#     openjpeg-2.4.0             |       hb52868f_1         444 KB  conda-forge
#     openssl-1.1.1k             |       h7f98852_0         2.1 MB  conda-forge
#     opt_einsum-3.3.0           |     pyhd8ed1ab_1          53 KB  conda-forge
#     packaging-21.0             |     pyhd8ed1ab_0          35 KB  conda-forge
#     pandas-1.3.0               |   py37h219a48f_0        12.7 MB  conda-forge
#     pandoc-2.14.0.3            |       h7f98852_0        12.0 MB  conda-forge
#     pandocfilters-1.4.2        |             py_1           9 KB  conda-forge
#     parso-0.8.2                |     pyhd8ed1ab_0          68 KB  conda-forge
#     partd-1.2.0                |     pyhd8ed1ab_0          18 KB  conda-forge
#     patsy-0.5.1                |             py_0         187 KB  conda-forge
#     pcre-8.45                  |       h9c3ff4c_0         253 KB  conda-forge
#     pexpect-4.8.0              |     pyh9f0ad1d_2          47 KB  conda-forge
#     pickleshare-0.7.5          |          py_1003           9 KB  conda-forge
#     pillow-8.3.0               |   py37h0f21c89_0         692 KB  conda-forge
#     pip-21.1.3                 |     pyhd8ed1ab_0         1.1 MB  conda-forge
#     plotly-5.1.0               |     pyhd8ed1ab_0         6.7 MB  conda-forge
#     pluggy-0.13.1              |   py37h89c1867_4          29 KB  conda-forge
#     pooch-1.4.0                |     pyhd8ed1ab_0          41 KB  conda-forge
#     prometheus_client-0.11.0   |     pyhd8ed1ab_0          46 KB  conda-forge
#     prompt-toolkit-3.0.19      |     pyha770c72_0         244 KB  conda-forge
#     protobuf-3.17.2            |   py37hcd2ae1e_0         347 KB  conda-forge
#     psycopg2-2.9.1             |   py37h5e8e339_0         178 KB  conda-forge
#     pthread-stubs-0.4          |    h36c2ea0_1001           5 KB  conda-forge
#     ptyprocess-0.7.0           |     pyhd3deb0d_0          16 KB  conda-forge
#     py-1.10.0                  |     pyhd3deb0d_0          73 KB  conda-forge
#     py-xgboost-1.4.0           |   py37h89c1867_0         141 KB  conda-forge
#     pyasn1-0.4.8               |             py_0          53 KB  conda-forge
#     pyasn1-modules-0.2.7       |             py_0          60 KB  conda-forge
#     pycparser-2.20             |     pyh9f0ad1d_2          94 KB  conda-forge
#     pyerfa-2.0.0               |   py37h6f94858_0         445 KB  conda-forge
#     pygments-2.9.0             |     pyhd8ed1ab_0         754 KB  conda-forge
#     pyjwt-2.1.0                |     pyhd8ed1ab_0          17 KB  conda-forge
#     pymssql-2.1.5              |   py37hcd2ae1e_2         264 KB  conda-forge
#     pyodbc-4.0.31              |   py37hcd2ae1e_0          74 KB  conda-forge
#     pyopenssl-20.0.1           |     pyhd8ed1ab_0          48 KB  conda-forge
#     pyparsing-2.4.7            |     pyh9f0ad1d_0          60 KB  conda-forge
#     pyqt-5.12.3                |   py37h89c1867_7          21 KB  conda-forge
#     pyqt-impl-5.12.3           |   py37he336c9b_7         5.9 MB  conda-forge
#     pyqt5-sip-4.19.18          |   py37hcd2ae1e_7         310 KB  conda-forge
#     pyqtchart-5.12             |   py37he336c9b_7         256 KB  conda-forge
#     pyqtwebengine-5.12.1       |   py37he336c9b_7         175 KB  conda-forge
#     pyrsistent-0.17.3          |   py37h5e8e339_2          89 KB  conda-forge
#     pyshp-2.1.0                |             py_0          31 KB  conda-forge
#     pysocks-1.7.1              |   py37h89c1867_3          27 KB  conda-forge
#     pytables-3.6.1             |   py37h0c4f3e0_3         1.5 MB  conda-forge
#     pytest-6.2.4               |   py37h89c1867_0         432 KB  conda-forge
#     python-3.7.10              |hffdb5ce_100_cpython        57.3 MB  conda-forge
#     python-dateutil-2.8.1      |             py_0         220 KB  conda-forge
#     python_abi-3.7             |          2_cp37m           4 KB  conda-forge
#     pytorch-1.7.1              |cpu_py37hf1c21f6_2        39.7 MB  conda-forge
#     pytz-2021.1                |     pyhd8ed1ab_0         239 KB  conda-forge
#     pyu2f-0.1.5                |     pyhd8ed1ab_0          31 KB  conda-forge
#     pywavelets-1.1.1           |   py37h902c9e0_3         4.4 MB  conda-forge
#     pyyaml-5.4.1               |   py37h5e8e339_0         189 KB  conda-forge
#     pyzmq-22.1.0               |   py37h336d617_0         500 KB  conda-forge
#     qt-5.12.9                  |       hda022c4_4        99.5 MB  conda-forge
#     readline-8.1               |       h46c0cb4_0         295 KB  conda-forge
#     regex-2021.7.6             |   py37h5e8e339_0         371 KB  conda-forge
#     requests-2.25.1            |     pyhd3deb0d_0          51 KB  conda-forge
#     requests-oauthlib-1.3.0    |     pyh9f0ad1d_0          21 KB  conda-forge
#     retrying-1.3.3             |             py_2          11 KB  conda-forge
#     rsa-4.7.2                  |     pyh44b312d_0          28 KB  conda-forge
#     s3transfer-0.4.2           |     pyhd8ed1ab_0          55 KB  conda-forge
#     scikit-image-0.18.1        |   py37hdc94413_0        11.5 MB  conda-forge
#     scikit-learn-0.24.2        |   py37h18a542f_0         7.5 MB  conda-forge
#     scipy-1.5.3                |   py37h8911b10_0        18.5 MB  conda-forge
#     seaborn-0.11.1             |       hd8ed1ab_1           4 KB  conda-forge
#     seaborn-base-0.11.1        |     pyhd8ed1ab_1         217 KB  conda-forge
#     secretstorage-3.3.1        |   py37h89c1867_0          24 KB  conda-forge
#     send2trash-1.7.1           |     pyhd8ed1ab_0          17 KB  conda-forge
#     setuptools-49.6.0          |   py37h89c1867_3         947 KB  conda-forge
#     sip-4.19.25                |   py37hcd2ae1e_0         295 KB  conda-forge
#     six-1.15.0                 |     pyh9f0ad1d_0          14 KB  conda-forge
#     snappy-1.1.8               |       he1b5a44_3          32 KB  conda-forge
#     snowballstemmer-2.1.0      |     pyhd8ed1ab_0          57 KB  conda-forge
#     soupsieve-2.0.1            |             py_1          30 KB  conda-forge
#     sqlalchemy-1.4.20          |   py37h5e8e339_0         2.3 MB  conda-forge
#     sqlite-3.36.0              |       h9cd32fc_0         1.4 MB  conda-forge
#     statsmodels-0.12.2         |   py37h902c9e0_0        11.3 MB  conda-forge
#     sympy-1.8                  |   py37h89c1867_0        11.1 MB  conda-forge
#     tabulate-0.8.9             |     pyhd8ed1ab_0          26 KB  conda-forge
#     tenacity-7.0.0             |     pyhd8ed1ab_0          20 KB  conda-forge
#     tensorboard-1.14.0         |           py37_0         3.2 MB  conda-forge
#     tensorflow-base-1.14.0     |   py37h4531e10_0        87.6 MB  conda-forge
#     tensorflow-estimator-1.14.0|   py37h5ca1d4c_0         645 KB  conda-forge
#     termcolor-1.1.0            |             py_2           6 KB  conda-forge
#     terminado-0.10.1           |   py37h89c1867_0          26 KB  conda-forge
#     testpath-0.5.0             |     pyhd8ed1ab_0          86 KB  conda-forge
#     threadpoolctl-2.1.0        |     pyh5ca1d4c_0          15 KB  conda-forge
#     tifffile-2021.7.2          |     pyhd8ed1ab_0         133 KB  conda-forge
#     tk-8.6.10                  |       h21135ba_1         3.2 MB  conda-forge
#     toml-0.10.2                |     pyhd8ed1ab_0          18 KB  conda-forge
#     toolz-0.11.1               |             py_0          46 KB  conda-forge
#     tornado-6.1                |   py37h5e8e339_1         646 KB  conda-forge
#     tqdm-4.61.1                |     pyhd8ed1ab_0          79 KB  conda-forge
#     traitlets-5.0.5            |             py_0          81 KB  conda-forge
#     typing-extensions-3.10.0.0 |       hd8ed1ab_0           8 KB  conda-forge
#     typing_extensions-3.10.0.0 |     pyha770c72_0          28 KB  conda-forge
#     unixodbc-2.3.9             |       hb166930_0         293 KB  conda-forge
#     urllib3-1.26.6             |     pyhd8ed1ab_0          99 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     wcwidth-0.2.5              |     pyh9f0ad1d_2          33 KB  conda-forge
#     webencodings-0.5.1         |             py_1          12 KB  conda-forge
#     werkzeug-2.0.1             |     pyhd8ed1ab_0         219 KB  conda-forge
#     wheel-0.36.2               |     pyhd3deb0d_0          31 KB  conda-forge
#     widgetsnbextension-3.5.1   |   py37h89c1867_4         1.8 MB  conda-forge
#     wrapt-1.12.1               |   py37h5e8e339_3          47 KB  conda-forge
#     xlrd-2.0.1                 |     pyhd8ed1ab_3          92 KB  conda-forge
#     xlsxwriter-1.4.4           |     pyhd8ed1ab_0         108 KB  conda-forge
#     xorg-libxau-1.0.9          |       h7f98852_0          13 KB  conda-forge
#     xorg-libxdmcp-1.1.3        |       h7f98852_0          19 KB  conda-forge
#     xz-5.2.5                   |       h516909a_1         343 KB  conda-forge
#     yaml-0.2.5                 |       h516909a_0          82 KB  conda-forge
#     yarl-1.6.3                 |   py37h5e8e339_2         142 KB  conda-forge
#     zeromq-4.3.4               |       h9c3ff4c_0         352 KB  conda-forge
#     zfp-0.5.5                  |       h9c3ff4c_5         190 KB  conda-forge
#     zipp-3.5.0                 |     pyhd8ed1ab_0          12 KB  conda-forge
#     zlib-1.2.11                |    h516909a_1010         106 KB  conda-forge
#     zstd-1.5.0                 |       ha95c52a_0         490 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       845.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-1_llvm
#   alsa-lib           conda-forge/linux-64::alsa-lib-1.2.3-h516909a_0
#   altair             conda-forge/noarch::altair-4.1.0-py_1
#   appdirs            conda-forge/noarch::appdirs-1.4.4-pyh9f0ad1d_0
#   argon2-cffi        conda-forge/linux-64::argon2-cffi-20.1.0-py37h5e8e339_2
#   async_generator    conda-forge/noarch::async_generator-1.10-py_0
#   backports          conda-forge/noarch::backports-1.0-py_2
#   backports.functoo~ conda-forge/noarch::backports.functools_lru_cache-1.6.4-pyhd8ed1ab_0
#   branca             conda-forge/noarch::branca-0.4.2-pyhd8ed1ab_0
#   brotli             conda-forge/linux-64::brotli-1.0.9-h7f98852_5
#   brotli-bin         conda-forge/linux-64::brotli-bin-1.0.9-h7f98852_5
#   brunsli            conda-forge/linux-64::brunsli-0.1-h9c3ff4c_0
#   cached-property    conda-forge/noarch::cached-property-1.5.2-hd8ed1ab_1
#   cached_property    conda-forge/noarch::cached_property-1.5.2-pyha770c72_1
#   cfitsio            conda-forge/linux-64::cfitsio-3.470-h2e3daa1_7
#   charls             conda-forge/linux-64::charls-2.2.0-h9c3ff4c_0
#   dataclasses        conda-forge/noarch::dataclasses-0.8-pyhc8e2a94_1
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   fsspec             conda-forge/noarch::fsspec-2021.6.1-pyhd8ed1ab_0
#   gettext            conda-forge/linux-64::gettext-0.19.8.1-h0b5b191_1005
#   giflib             conda-forge/linux-64::giflib-5.2.1-h36c2ea0_2
#   glib-tools         conda-forge/linux-64::glib-tools-2.68.3-h9c3ff4c_0
#   gmpy2              conda-forge/linux-64::gmpy2-2.1.0b5-py37h025e8b9_0
#   greenlet           conda-forge/linux-64::greenlet-1.1.0-py37hcd2ae1e_0
#   ibm-wsrt-py37main~ opt/ibm/build/channels/wscloud/noarch::ibm-wsrt-py37main-keep-0.0.0-2527
#   imagecodecs        conda-forge/linux-64::imagecodecs-2021.6.8-py37hd3505d4_0
#   iniconfig          conda-forge/noarch::iniconfig-1.1.1-pyh9f0ad1d_0
#   jbig               conda-forge/linux-64::jbig-2.1-h7f98852_2003
#   jupyterlab_pygmen~ conda-forge/noarch::jupyterlab_pygments-0.1.2-pyh9f0ad1d_0
#   jupyterlab_widgets conda-forge/noarch::jupyterlab_widgets-1.0.0-pyhd8ed1ab_1
#   jxrlib             conda-forge/linux-64::jxrlib-1.1-h7f98852_2
#   lerc               conda-forge/linux-64::lerc-2.2.1-h9c3ff4c_0
#   libaec             conda-forge/linux-64::libaec-1.0.5-h9c3ff4c_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-8_mkl
#   libbrotlicommon    conda-forge/linux-64::libbrotlicommon-1.0.9-h7f98852_5
#   libbrotlidec       conda-forge/linux-64::libbrotlidec-1.0.9-h7f98852_5
#   libbrotlienc       conda-forge/linux-64::libbrotlienc-1.0.9-h7f98852_5
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-8_mkl
#   libclang           conda-forge/linux-64::libclang-11.1.0-default_ha53f305_1
#   libcurl            conda-forge/linux-64::libcurl-7.77.0-h2574ce0_0
#   libdeflate         conda-forge/linux-64::libdeflate-1.7-h7f98852_5
#   libev              conda-forge/linux-64::libev-4.33-h516909a_1
#   libevent           conda-forge/linux-64::libevent-2.1.10-hcdb4288_3
#   libgfortran4       conda-forge/linux-64::libgfortran4-7.5.0-h14aa051_19
#   libglib            conda-forge/linux-64::libglib-2.68.3-h3e27bee_0
#   libiconv           conda-forge/linux-64::libiconv-1.16-h516909a_0
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-8_mkl
#   libllvm11          conda-forge/linux-64::libllvm11-11.1.0-hf817b99_2
#   libnghttp2         conda-forge/linux-64::libnghttp2-1.43.0-h812cca2_0
#   libogg             conda-forge/linux-64::libogg-1.3.4-h7f98852_1
#   libopus            conda-forge/linux-64::libopus-1.3.1-h7f98852_1
#   libssh2            conda-forge/linux-64::libssh2-1.9.0-ha56f1ee_6
#   libvorbis          conda-forge/linux-64::libvorbis-1.3.7-h9c3ff4c_0
#   libxkbcommon       conda-forge/linux-64::libxkbcommon-1.0.3-he3ba5ed_0
#   libzopfli          conda-forge/linux-64::libzopfli-1.0.3-h9c3ff4c_0
#   llvm-openmp        conda-forge/linux-64::llvm-openmp-11.1.0-h4bd325d_1
#   locket             conda-forge/noarch::locket-0.2.0-py_2
#   matplotlib-inline  conda-forge/noarch::matplotlib-inline-0.1.2-pyhd8ed1ab_2
#   mpc                conda-forge/linux-64::mpc-1.1.0-h04dde30_1009
#   mpfr               conda-forge/linux-64::mpfr-4.0.2-he80fd80_1
#   mysql-common       conda-forge/linux-64::mysql-common-8.0.25-ha770c72_2
#   mysql-libs         conda-forge/linux-64::mysql-libs-8.0.25-hfa10184_2
#   nbclient           conda-forge/noarch::nbclient-0.5.3-pyhd8ed1ab_0
#   nest-asyncio       conda-forge/noarch::nest-asyncio-1.5.1-pyhd8ed1ab_0
#   nspr               conda-forge/linux-64::nspr-4.30-h9c3ff4c_0
#   nss                conda-forge/linux-64::nss-3.67-hb5efdd6_0
#   openjpeg           conda-forge/linux-64::openjpeg-2.4.0-hb52868f_1
#   partd              conda-forge/noarch::partd-1.2.0-pyhd8ed1ab_0
#   pooch              conda-forge/noarch::pooch-1.4.0-pyhd8ed1ab_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h36c2ea0_1001
#   pyerfa             conda-forge/linux-64::pyerfa-2.0.0-py37h6f94858_0
#   pyqt-impl          conda-forge/linux-64::pyqt-impl-5.12.3-py37he336c9b_7
#   pyqt5-sip          conda-forge/linux-64::pyqt5-sip-4.19.18-py37hcd2ae1e_7
#   pyqtchart          conda-forge/linux-64::pyqtchart-5.12-py37he336c9b_7
#   pyqtwebengine      conda-forge/linux-64::pyqtwebengine-5.12.1-py37he336c9b_7
#   python_abi         conda-forge/linux-64::python_abi-3.7-2_cp37m
#   pyu2f              conda-forge/noarch::pyu2f-0.1.5-pyhd8ed1ab_0
#   seaborn-base       conda-forge/noarch::seaborn-base-0.11.1-pyhd8ed1ab_1
#   tenacity           conda-forge/noarch::tenacity-7.0.0-pyhd8ed1ab_0
#   tifffile           conda-forge/noarch::tifffile-2021.7.2-pyhd8ed1ab_0
#   toml               conda-forge/noarch::toml-0.10.2-pyhd8ed1ab_0
#   typing-extensions  conda-forge/noarch::typing-extensions-3.10.0.0-hd8ed1ab_0
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.9-h7f98852_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h7f98852_0
#   zfp                conda-forge/linux-64::zfp-0.5.5-h9c3ff4c_5
#
# The following packages will be UPDATED:
#
#   _py-xgboost-mutex                               pkgs/main --> conda-forge
#   _pytorch_select                                 0.1-cpu_0 --> 0.2-gpu_0
#   absl-py            pkgs/main/linux-64::absl-py-0.9.0-py3~ --> conda-forge/noarch::absl-py-0.13.0-pyhd8ed1ab_0
#   aiohttp            pkgs/main::aiohttp-3.6.2-py37h7b6447c~ --> conda-forge::aiohttp-3.7.4.post0-py37h5e8e339_0
#   astor              pkgs/main/linux-64::astor-0.8.0-py37_0 --> conda-forge/noarch::astor-0.8.1-pyh9f0ad1d_0
#   astropy            pkgs/main::astropy-4.0.1.post1-py37h7~ --> conda-forge::astropy-4.2.1-py37h5e8e339_0
#   async-timeout      pkgs/main/linux-64::async-timeout-3.0~ --> conda-forge/noarch::async-timeout-3.0.1-py_1000
#   attrs                        pkgs/main::attrs-19.3.0-py_0 --> conda-forge::attrs-21.2.0-pyhd8ed1ab_0
#   beautifulsoup4     pkgs/main/linux-64::beautifulsoup4-4.~ --> conda-forge/noarch::beautifulsoup4-4.9.3-pyhb0f4dca_0
#   biopython          pkgs/main::biopython-1.77-py37h27cfd2~ --> conda-forge::biopython-1.79-py37h5e8e339_0
#   bleach                       pkgs/main::bleach-3.1.5-py_0 --> conda-forge::bleach-3.3.0-pyh44b312d_0
#   blinker            pkgs/main/linux-64::blinker-1.4-py37h~ --> conda-forge/noarch::blinker-1.4-py_1
#   blosc                  pkgs/main::blosc-1.19.0-hd408876_0 --> conda-forge::blosc-1.21.0-h9c3ff4c_0
#   bokeh                       pkgs/main::bokeh-2.1.1-py37_0 --> conda-forge::bokeh-2.3.2-py37h89c1867_0
#   boto3                       pkgs/main::boto3-1.13.11-py_0 --> conda-forge::boto3-1.17.105-pyhd8ed1ab_0
#   botocore                 pkgs/main::botocore-1.16.11-py_0 --> conda-forge::botocore-1.20.105-pyhd8ed1ab_0
#   bzip2                   pkgs/main::bzip2-1.0.8-h7b6447c_0 --> conda-forge::bzip2-1.0.8-h7f98852_4
#   c-ares             pkgs/main::c-ares-1.15.0-h7b6447c_1001 --> conda-forge::c-ares-1.17.1-h7f98852_1
#   ca-certificates    pkgs/main::ca-certificates-2021.5.25-~ --> conda-forge::ca-certificates-2021.5.30-ha878542_0
#   cachetools               pkgs/main::cachetools-4.1.1-py_0 --> conda-forge::cachetools-4.2.2-pyhd8ed1ab_0
#   cffi                pkgs/main::cffi-1.14.0-py37he30daa8_1 --> conda-forge::cffi-1.14.5-py37hc58025e_0
#   chardet            pkgs/main::chardet-3.0.4-py37h06a4308~ --> conda-forge::chardet-4.0.0-py37h89c1867_1
#   click              pkgs/main/noarch::click-7.1.2-pyhd3eb~ --> conda-forge/linux-64::click-8.0.1-py37h89c1867_0
#   cloudpickle             pkgs/main::cloudpickle-1.5.0-py_0 --> conda-forge::cloudpickle-1.6.0-py_0
#   cx_oracle          pkgs/main::cx_oracle-7.2.3-py37h7b644~ --> conda-forge::cx_oracle-8.2.1-py37h5e8e339_0
#   cycler             pkgs/main/linux-64::cycler-0.10.0-py3~ --> conda-forge/noarch::cycler-0.10.0-py_2
#   cytoolz            pkgs/main::cytoolz-0.10.1-py37h7b6447~ --> conda-forge::cytoolz-0.11.0-py37h5e8e339_3
#   dask-core                pkgs/main::dask-core-2.20.0-py_0 --> conda-forge::dask-core-2021.6.2-pyhd8ed1ab_0
#   decorator          pkgs/main::decorator-4.4.2-pyhd3eb1b0~ --> conda-forge::decorator-5.0.9-pyhd8ed1ab_0
#   defusedxml         pkgs/main::defusedxml-0.6.0-pyhd3eb1b~ --> conda-forge::defusedxml-0.7.1-pyhd8ed1ab_0
#   dill                pkgs/main/linux-64::dill-0.3.0-py37_0 --> conda-forge/noarch::dill-0.3.4-pyhd8ed1ab_0
#   docutils           pkgs/main::docutils-0.15.2-py37h06a43~ --> conda-forge::docutils-0.17.1-py37h89c1867_0
#   entrypoints        pkgs/main/linux-64::entrypoints-0.3-p~ --> conda-forge/noarch::entrypoints-0.3-pyhd8ed1ab_1003
#   expat                   pkgs/main::expat-2.2.9-he6710b0_2 --> conda-forge::expat-2.4.1-h9c3ff4c_0
#   fastcache          pkgs/main::fastcache-1.1.0-py37h7b644~ --> conda-forge::fastcache-1.1.0-py37h5e8e339_2
#   fontconfig         pkgs/main::fontconfig-2.13.0-h9420a91~ --> conda-forge::fontconfig-2.13.1-hba837de_1005
#   freetds             pkgs/main::freetds-1.00.97-h52ef933_0 --> conda-forge::freetds-1.1.15-h94af77a_0
#   freetype            pkgs/main::freetype-2.10.2-h5ab3b9f_0 --> conda-forge::freetype-2.10.4-h0708190_1
#   future                    pkgs/main::future-0.18.2-py37_1 --> conda-forge::future-0.18.2-py37h89c1867_3
#   gast                pkgs/main/linux-64::gast-0.2.2-py37_0 --> conda-forge/noarch::gast-0.5.0-pyhd8ed1ab_0
#   glib                    pkgs/main::glib-2.65.0-h3eb4bd4_0 --> conda-forge::glib-2.68.3-h9c3ff4c_0
#   gmp                       pkgs/main::gmp-6.1.2-h6c8ec71_1 --> conda-forge::gmp-6.2.1-h58526e2_0
#   google-auth            pkgs/main::google-auth-1.22.0-py_0 --> conda-forge::google-auth-1.32.1-pyh6c4a22f_0
#   google-auth-oauth~ pkgs/main::google-auth-oauthlib-0.4.1~ --> conda-forge::google-auth-oauthlib-0.4.4-pyhd8ed1ab_0
#   grpcio             pkgs/main::grpcio-1.27.2-py37hf8bcb03~ --> conda-forge::grpcio-1.38.1-py37hb27c1af_0
#   gst-plugins-base   pkgs/main::gst-plugins-base-1.14.0-hb~ --> conda-forge::gst-plugins-base-1.18.4-hf529b03_2
#   gstreamer          pkgs/main::gstreamer-1.14.0-hb31296c_0 --> conda-forge::gstreamer-1.18.4-h76c114f_2
#   h5py                pkgs/main::h5py-2.10.0-py37h7918eee_0 --> conda-forge::h5py-3.3.0-nompi_py37ha3df211_100
#   hdf5                    pkgs/main::hdf5-1.10.4-hb1b8bf9_0 --> conda-forge::hdf5-1.10.6-nompi_h7c3c948_1111
#   icu                        pkgs/main::icu-58.2-he6710b0_3 --> conda-forge::icu-68.1-h58526e2_0
#   idna                             pkgs/main::idna-2.9-py_1 --> conda-forge::idna-2.10-pyh9f0ad1d_0
#   importlib-metadata pkgs/main::importlib-metadata-1.6.1-p~ --> conda-forge::importlib-metadata-4.6.1-py37h89c1867_0
#   importlib_metadata  pkgs/main::importlib_metadata-1.6.1-0 --> conda-forge::importlib_metadata-4.6.1-hd8ed1ab_0
#   ipykernel          pkgs/main::ipykernel-5.3.0-py37h5ca1d~ --> conda-forge::ipykernel-5.5.5-py37h085eea5_0
#   ipython                  pkgs/main::ipython-7.15.0-py37_0 --> conda-forge::ipython-7.25.0-py37h085eea5_1
#   ipywidgets               pkgs/main::ipywidgets-7.5.1-py_1 --> conda-forge::ipywidgets-7.6.3-pyhd3deb0d_0
#   jedi                        pkgs/main::jedi-0.17.1-py37_0 --> conda-forge::jedi-0.18.0-py37h89c1867_2
#   jeepney            pkgs/main/linux-64::jeepney-0.4-py37_0 --> conda-forge/noarch::jeepney-0.6.0-pyhd8ed1ab_0
#   jinja2              pkgs/main::jinja2-2.11.3-pyhd3eb1b0_0 --> conda-forge::jinja2-3.0.1-pyhd8ed1ab_0
#   jmespath                   pkgs/main::jmespath-0.9.4-py_0 --> conda-forge::jmespath-0.10.0-pyh9f0ad1d_0
#   joblib                      pkgs/main::joblib-0.16.0-py_0 --> conda-forge::joblib-1.0.1-pyhd8ed1ab_0
#   jpeg                        pkgs/main::jpeg-9b-h024ee3a_2 --> conda-forge::jpeg-9d-h36c2ea0_0
#   jsonschema               pkgs/main::jsonschema-3.2.0-py_2 --> conda-forge::jsonschema-3.2.0-pyhd8ed1ab_3
#   jupyter_client       pkgs/main::jupyter_client-6.1.3-py_0 --> conda-forge::jupyter_client-6.1.12-pyhd8ed1ab_0
#   jupyter_core         pkgs/main::jupyter_core-4.6.3-py37_0 --> conda-forge::jupyter_core-4.7.1-py37h89c1867_0
#   jupyterlab_server  pkgs/main::jupyterlab_server-1.1.0-py~ --> conda-forge::jupyterlab_server-1.2.0-py_0
#   keras-preprocessi~ pkgs/main::keras-preprocessing-1.1.0-~ --> conda-forge::keras-preprocessing-1.1.2-pyhd8ed1ab_0
#   kiwisolver         pkgs/main::kiwisolver-1.2.0-py37hfd86~ --> conda-forge::kiwisolver-1.3.1-py37h2527ec5_1
#   krb5                    pkgs/main::krb5-1.17.1-h173b8e3_0 --> conda-forge::krb5-1.19.1-hcc1bbae_0
#   lcms2                    pkgs/main::lcms2-2.11-h396b838_0 --> conda-forge::lcms2-2.12-hddcbb42_0
#   ld_impl_linux-64   pkgs/main::ld_impl_linux-64-2.33.1-h5~ --> conda-forge::ld_impl_linux-64-2.36.1-hea4e1c9_0
#   libedit            pkgs/main::libedit-3.1.20191231-h14c3~ --> conda-forge::libedit-3.1.20191231-he28a2e2_2
#   libgcc-ng           pkgs/main::libgcc-ng-9.1.0-hdf63c60_0 --> conda-forge::libgcc-ng-9.3.0-h2828fa1_19
#   libgfortran-ng     pkgs/main::libgfortran-ng-7.3.0-hdf63~ --> conda-forge::libgfortran-ng-7.5.0-h14aa051_19
#   libpng                pkgs/main::libpng-1.6.37-hbc83047_0 --> conda-forge::libpng-1.6.37-h21135ba_2
#   libpq                    pkgs/main::libpq-12.2-h20c2e04_0 --> conda-forge::libpq-13.3-hd57d9b9_0
#   libprotobuf        pkgs/main::libprotobuf-3.12.3-hd40887~ --> conda-forge::libprotobuf-3.17.2-h780b84a_0
#   libsodium          pkgs/main::libsodium-1.0.18-h7b6447c_0 --> conda-forge::libsodium-1.0.18-h36c2ea0_1
#   libstdcxx-ng       pkgs/main::libstdcxx-ng-9.1.0-hdf63c6~ --> conda-forge::libstdcxx-ng-9.3.0-h6de172a_19
#   libtiff               pkgs/main::libtiff-4.2.0-h85742a9_0 --> conda-forge::libtiff-4.3.0-hf544144_1
#   libuuid               pkgs/main::libuuid-1.0.3-h1bed415_2 --> conda-forge::libuuid-2.32.1-h7f98852_1000
#   libwebp-base       pkgs/main::libwebp-base-1.2.0-h27cfd2~ --> conda-forge::libwebp-base-1.2.0-h7f98852_2
#   libxgboost          pkgs/main::libxgboost-0.90-he6710b0_1 --> conda-forge::libxgboost-1.4.0-h9c3ff4c_0
#   libxml2              pkgs/main::libxml2-2.9.10-hb55368b_3 --> conda-forge::libxml2-2.9.12-h72842e0_0
#   lz4-c                   pkgs/main::lz4-c-1.9.2-heb0550a_3 --> conda-forge::lz4-c-1.9.3-h9c3ff4c_0
#   lzo                        pkgs/main::lzo-2.10-h7b6447c_2 --> conda-forge::lzo-2.10-h516909a_1000
#   markdown           pkgs/main/linux-64::markdown-3.1.1-py~ --> conda-forge/noarch::markdown-3.3.4-pyhd8ed1ab_0
#   markupsafe         pkgs/main::markupsafe-1.1.1-py37h14c3~ --> conda-forge::markupsafe-2.0.1-py37h5e8e339_0
#   matplotlib                  pkgs/main::matplotlib-3.2.2-0 --> conda-forge::matplotlib-3.4.2-py37h89c1867_0
#   matplotlib-base    pkgs/main::matplotlib-base-3.2.2-py37~ --> conda-forge::matplotlib-base-3.4.2-py37hdd32ed1_0
#   mistune            pkgs/main::mistune-0.8.4-py37h14c3975~ --> conda-forge::mistune-0.8.4-py37h5e8e339_1004
#   mkl                             pkgs/main::mkl-2020.1-217 --> conda-forge::mkl-2020.4-h726a3e6_304
#   mkl-service        pkgs/main::mkl-service-2.3.0-py37he8a~ --> conda-forge::mkl-service-2.3.0-py37h8f50634_2
#   mkl_fft            pkgs/main::mkl_fft-1.1.0-py37h23d657b~ --> conda-forge::mkl_fft-1.3.0-py37h902c9e0_1
#   mkl_random         pkgs/main::mkl_random-1.1.1-py37h0573~ --> conda-forge::mkl_random-1.2.0-py37h9fdb41a_1
#   mock                    pkgs/main/noarch::mock-4.0.2-py_0 --> conda-forge/linux-64::mock-4.0.3-py37h89c1867_1
#   more-itertools       pkgs/main::more-itertools-8.4.0-py_0 --> conda-forge::more-itertools-8.8.0-pyhd8ed1ab_0
#   mpmath             pkgs/main/linux-64::mpmath-1.1.0-py37~ --> conda-forge/noarch::mpmath-1.2.1-pyhd8ed1ab_0
#   multidict          pkgs/main::multidict-4.7.6-py37h7b644~ --> conda-forge::multidict-5.1.0-py37h5e8e339_1
#   nbconvert               pkgs/main::nbconvert-5.6.1-py37_1 --> conda-forge::nbconvert-6.1.0-py37h89c1867_0
#   nbformat                   pkgs/main::nbformat-5.0.7-py_0 --> conda-forge::nbformat-5.1.3-pyhd8ed1ab_0
#   ncurses                 pkgs/main::ncurses-6.2-he6710b0_1 --> conda-forge::ncurses-6.2-h58526e2_4
#   networkx                     pkgs/main::networkx-2.4-py_1 --> conda-forge::networkx-2.5-py_0
#   ninja               pkgs/main::ninja-1.9.0-py37hfd86e86_0 --> conda-forge::ninja-1.10.2-h4bd325d_0
#   nltk                             pkgs/main::nltk-3.5-py_0 --> conda-forge::nltk-3.6.2-pyhd8ed1ab_0
#   notebook           pkgs/main/linux-64::notebook-6.0.3-py~ --> conda-forge/noarch::notebook-6.4.0-pyha770c72_0
#   numexpr            pkgs/main::numexpr-2.7.1-py37h63df603~ --> conda-forge::numexpr-2.7.3-py37hdc94413_0
#   numpy              pkgs/main::numpy-1.18.5-py37ha1c710e_0 --> conda-forge::numpy-1.20.3-py37h038b26d_0
#   oauthlib                   pkgs/main::oauthlib-3.1.0-py_0 --> conda-forge::oauthlib-3.1.1-pyhd8ed1ab_0
#   olefile            pkgs/main/linux-64::olefile-0.46-py37~ --> conda-forge/noarch::olefile-0.46-pyh9f0ad1d_1
#   opt_einsum               pkgs/main::opt_einsum-3.1.0-py_0 --> conda-forge::opt_einsum-3.3.0-pyhd8ed1ab_1
#   packaging                  pkgs/main::packaging-20.4-py_0 --> conda-forge::packaging-21.0-pyhd8ed1ab_0
#   pandas             pkgs/main::pandas-1.0.5-py37h0573a6f_0 --> conda-forge::pandas-1.3.0-py37h219a48f_0
#   pandoc                        pkgs/main::pandoc-2.9.2.1-0 --> conda-forge::pandoc-2.14.0.3-h7f98852_0
#   parso                         pkgs/main::parso-0.7.0-py_0 --> conda-forge::parso-0.8.2-pyhd8ed1ab_0
#   pcre                      pkgs/main::pcre-8.44-he6710b0_0 --> conda-forge::pcre-8.45-h9c3ff4c_0
#   pillow             pkgs/main::pillow-7.2.0-py37hb39fc2d_0 --> conda-forge::pillow-8.3.0-py37h0f21c89_0
#   pip                 pkgs/main/linux-64::pip-20.1.1-py37_1 --> conda-forge/noarch::pip-21.1.3-pyhd8ed1ab_0
#   plotly                       pkgs/main::plotly-4.8.2-py_0 --> conda-forge::plotly-5.1.0-pyhd8ed1ab_0
#   pluggy             pkgs/main::pluggy-0.13.1-py37h06a4308~ --> conda-forge::pluggy-0.13.1-py37h89c1867_4
#   prometheus_client  pkgs/main::prometheus_client-0.8.0-py~ --> conda-forge::prometheus_client-0.11.0-pyhd8ed1ab_0
#   prompt-toolkit     pkgs/main::prompt-toolkit-3.0.5-pyha8~ --> conda-forge::prompt-toolkit-3.0.19-pyha770c72_0
#   protobuf           pkgs/main::protobuf-3.12.3-py37he6710~ --> conda-forge::protobuf-3.17.2-py37hcd2ae1e_0
#   psycopg2           pkgs/main::psycopg2-2.8.5-py37h3c74f8~ --> conda-forge::psycopg2-2.9.1-py37h5e8e339_0
#   ptyprocess         pkgs/main::ptyprocess-0.6.0-pyhd3eb1b~ --> conda-forge::ptyprocess-0.7.0-pyhd3deb0d_0
#   py                               pkgs/main::py-1.8.2-py_0 --> conda-forge::py-1.10.0-pyhd3deb0d_0
#   py-xgboost         pkgs/main::py-xgboost-0.90-py37he6710~ --> conda-forge::py-xgboost-1.4.0-py37h89c1867_0
#   pygments                   pkgs/main::pygments-2.6.1-py_0 --> conda-forge::pygments-2.9.0-pyhd8ed1ab_0
#   pyjwt              pkgs/main/linux-64::pyjwt-1.7.1-py37_0 --> conda-forge/noarch::pyjwt-2.1.0-pyhd8ed1ab_0
#   pymssql            pkgs/main::pymssql-2.1.5-py37h7b6447c~ --> conda-forge::pymssql-2.1.5-py37hcd2ae1e_2
#   pyodbc             pkgs/main::pyodbc-4.0.30-py37he6710b0~ --> conda-forge::pyodbc-4.0.31-py37hcd2ae1e_0
#   pyopenssl          pkgs/main::pyopenssl-19.1.0-pyhd3eb1b~ --> conda-forge::pyopenssl-20.0.1-pyhd8ed1ab_0
#   pyqt                 pkgs/main::pyqt-5.9.2-py37h05f1152_2 --> conda-forge::pyqt-5.12.3-py37h89c1867_7
#   pyrsistent         pkgs/main::pyrsistent-0.16.0-py37h7b6~ --> conda-forge::pyrsistent-0.17.3-py37h5e8e339_2
#   pysocks                   pkgs/main::pysocks-1.7.1-py37_1 --> conda-forge::pysocks-1.7.1-py37h89c1867_3
#   pytables           pkgs/main::pytables-3.6.1-py37h71ec23~ --> conda-forge::pytables-3.6.1-py37h0c4f3e0_3
#   pytest             pkgs/main::pytest-5.4.3-py37h06a4308_0 --> conda-forge::pytest-6.2.4-py37h89c1867_0
#   python                pkgs/main::python-3.7.10-hdb3f193_0 --> conda-forge::python-3.7.10-hffdb5ce_100_cpython
#   pytorch            pkgs/main::pytorch-1.3.1-cpu_py37h62f~ --> conda-forge::pytorch-1.7.1-cpu_py37hf1c21f6_2
#   pytz                          pkgs/main::pytz-2020.1-py_0 --> conda-forge::pytz-2021.1-pyhd8ed1ab_0
#   pywavelets         pkgs/main::pywavelets-1.1.1-py37h7b64~ --> conda-forge::pywavelets-1.1.1-py37h902c9e0_3
#   pyzmq              pkgs/main::pyzmq-19.0.1-py37he6710b0_1 --> conda-forge::pyzmq-22.1.0-py37h336d617_0
#   qt                         pkgs/main::qt-5.9.7-h5867ecd_1 --> conda-forge::qt-5.12.9-hda022c4_4
#   readline               pkgs/main::readline-8.0-h7b6447c_0 --> conda-forge::readline-8.1-h46c0cb4_0
#   regex              pkgs/main::regex-2020.6.8-py37h7b6447~ --> conda-forge::regex-2021.7.6-py37h5e8e339_0
#   requests                  pkgs/main::requests-2.24.0-py_0 --> conda-forge::requests-2.25.1-pyhd3deb0d_0
#   rsa                               pkgs/main::rsa-4.6-py_0 --> conda-forge::rsa-4.7.2-pyh44b312d_0
#   s3transfer         pkgs/main::s3transfer-0.3.3-pyhd3eb1b~ --> conda-forge::s3transfer-0.4.2-pyhd8ed1ab_0
#   scikit-image       pkgs/main::scikit-image-0.16.2-py37h0~ --> conda-forge::scikit-image-0.18.1-py37hdc94413_0
#   scikit-learn       pkgs/main::scikit-learn-0.23.1-py37h4~ --> conda-forge::scikit-learn-0.24.2-py37h18a542f_0
#   scipy               pkgs/main::scipy-1.5.0-py37h0b6359f_0 --> conda-forge::scipy-1.5.3-py37h8911b10_0
#   seaborn                    pkgs/main::seaborn-0.10.1-py_0 --> conda-forge::seaborn-0.11.1-hd8ed1ab_1
#   secretstorage       pkgs/main::secretstorage-3.1.0-py37_0 --> conda-forge::secretstorage-3.3.1-py37h89c1867_0
#   send2trash         pkgs/main::send2trash-1.5.0-pyhd3eb1b~ --> conda-forge::send2trash-1.7.1-pyhd8ed1ab_0
#   setuptools            pkgs/main::setuptools-47.3.1-py37_0 --> conda-forge::setuptools-49.6.0-py37h89c1867_3
#   sip                  pkgs/main::sip-4.19.8-py37hf484d3e_0 --> conda-forge::sip-4.19.25-py37hcd2ae1e_0
# ...
# grpcio-1.38.1        | 2.2 MB    | ##################################### | 100%
# libdeflate-1.7       | 67 KB     | ##################################### | 100%
# testpath-0.5.0       | 86 KB     | ##################################### | 100%
# botocore-1.20.105    | 4.7 MB    | ##################################### | 100%
# zfp-0.5.5            | 190 KB    | ##################################### | 100%
# notebook-6.4.0       | 6.1 MB    | ##################################### | 100%
# libxcb-1.13          | 395 KB    | ##################################### | 100%
# python_abi-3.7       | 4 KB      | ##################################### | 100%
# wrapt-1.12.1         | 47 KB     | ##################################### | 100%
# mock-4.0.3           | 51 KB     | ##################################### | 100%
# partd-1.2.0          | 18 KB     | ##################################### | 100%
# jeepney-0.6.0        | 32 KB     | ##################################### | 100%
# jmespath-0.10.0      | 21 KB     | ##################################### | 100%
# cloudpickle-1.6.0    | 22 KB     | ##################################### | 100%
# mpmath-1.2.1         | 437 KB    | ##################################### | 100%
# dbus-1.13.6          | 572 KB    | ##################################### | 100%
# tensorboard-1.14.0   | 3.2 MB    | ##################################### | 100%
# pygments-2.9.0       | 754 KB    | ##################################### | 100%
# libstdcxx-ng-9.3.0   | 4.0 MB    | ##################################### | 100%
# _pytorch_select-0.2  | 2 KB      | ##################################### | 100%
# pyparsing-2.4.7      | 60 KB     | ##################################### | 100%
# libnghttp2-1.43.0    | 808 KB    | ##################################### | 100%
# libtiff-4.3.0        | 668 KB    | ##################################### | 100%
# numpy-1.20.3         | 5.7 MB    | ##################################### | 100%
# astropy-4.2.1        | 7.5 MB    | ##################################### | 100%
# decorator-5.0.9      | 11 KB     | ##################################### | 100%
# py-1.10.0            | 73 KB     | ##################################### | 100%
# traitlets-5.0.5      | 81 KB     | ##################################### | 100%
# sqlalchemy-1.4.20    | 2.3 MB    | ##################################### | 100%
# werkzeug-2.0.1       | 219 KB    | ##################################### | 100%
# terminado-0.10.1     | 26 KB     | ##################################### | 100%
# libglib-2.68.3       | 3.1 MB    | ##################################### | 100%
# ibm-wsrt-py37main-ma | 2 KB      | ##################################### | 100%
# pycparser-2.20       | 94 KB     | ##################################### | 100%
# cycler-0.10.0        | 9 KB      | ##################################### | 100%
# typing-extensions-3. | 8 KB      | ##################################### | 100%
# libxgboost-1.4.0     | 3.3 MB    | ##################################### | 100%
# lxml-4.6.3           | 1.5 MB    | ##################################### | 100%
# pytz-2021.1          | 239 KB    | ##################################### | 100%
# libev-4.33           | 104 KB    | ##################################### | 100%
# pickleshare-0.7.5    | 9 KB      | ##################################### | 100%
# libffi-3.3           | 51 KB     | ##################################### | 100%
# tensorflow-base-1.14 | 87.6 MB   | ##################################### | 100%
# brotli-1.0.9         | 17 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# beautifulsoup4-4.9.3 | 86 KB     | ##################################### | 100%
# soupsieve-2.0.1      | 30 KB     | ##################################### | 100%
# xlsxwriter-1.4.4     | 108 KB    | ##################################### | 100%
# libblas-3.9.0        | 12 KB     | ##################################### | 100%
# aiohttp-3.7.4.post0  | 625 KB    | ##################################### | 100%
# charls-2.2.0         | 138 KB    | ##################################### | 100%
# pthread-stubs-0.4    | 5 KB      | ##################################### | 100%
# google-auth-1.32.1   | 78 KB     | ##################################### | 100%
# s3transfer-0.4.2     | 55 KB     | ##################################### | 100%
# tenacity-7.0.0       | 20 KB     | ##################################### | 100%
# llvm-openmp-11.1.0   | 4.7 MB    | ##################################### | 100%
# pyrsistent-0.17.3    | 89 KB     | ##################################### | 100%
# ncurses-6.2          | 985 KB    | ##################################### | 100%
# unixodbc-2.3.9       | 293 KB    | ##################################### | 100%
# pillow-8.3.0         | 692 KB    | ##################################### | 100%
# python-3.7.10        | 57.3 MB   | ##################################### | 100%
# blosc-1.21.0         | 841 KB    | ##################################### | 100%
# jpeg-9d              | 264 KB    | ##################################### | 100%
# cachetools-4.2.2     | 12 KB     | ##################################### | 100%
# jedi-0.18.0          | 923 KB    | ##################################### | 100%
# tensorflow-estimator | 645 KB    | ##################################### | 100%
# xz-5.2.5             | 343 KB    | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# pyqt5-sip-4.19.18    | 310 KB    | ##################################### | 100%
# dill-0.3.4           | 62 KB     | ##################################### | 100%
# wcwidth-0.2.5        | 33 KB     | ##################################### | 100%
# retrying-1.3.3       | 11 KB     | ##################################### | 100%
# pyqt-5.12.3          | 21 KB     | ##################################### | 100%
# pyjwt-2.1.0          | 17 KB     | ##################################### | 100%
# libgcc-ng-9.3.0      | 7.8 MB    | ##################################### | 100%
# zlib-1.2.11          | 106 KB    | ##################################### | 100%
# libogg-1.3.4         | 206 KB    | ##################################### | 100%
# libsodium-1.0.18     | 366 KB    | ##################################### | 100%
# future-0.18.2        | 714 KB    | ##################################### | 100%
# nbconvert-6.1.0      | 548 KB    | ##################################### | 100%
# alsa-lib-1.2.3       | 560 KB    | ##################################### | 100%
# threadpoolctl-2.1.0  | 15 KB     | ##################################### | 100%
# ptyprocess-0.7.0     | 16 KB     | ##################################### | 100%
# biopython-1.79       | 2.6 MB    | ##################################### | 100%
# jxrlib-1.1           | 235 KB    | ##################################### | 100%
# opt_einsum-3.3.0     | 53 KB     | ##################################### | 100%
# cx_oracle-8.2.1      | 199 KB    | ##################################### | 100%
# numexpr-2.7.3        | 201 KB    | ##################################### | 100%
# cached-property-1.5. | 4 KB      | ##################################### | 100%
# tornado-6.1          | 646 KB    | ##################################### | 100%
# yaml-0.2.5           | 82 KB     | ##################################### | 100%
# libcurl-7.77.0       | 334 KB    | ##################################### | 100%
# mysql-common-8.0.25  | 1.6 MB    | ##################################### | 100%
# nss-3.67             | 2.1 MB    | ##################################### | 100%
# urllib3-1.26.6       | 99 KB     | ##################################### | 100%
# cytoolz-0.11.0       | 403 KB    | ##################################### | 100%
# libgfortran-ng-7.5.0 | 22 KB     | ##################################### | 100%
# wheel-0.36.2         | 31 KB     | ##################################### | 100%
# matplotlib-3.4.2     | 7 KB      | ##################################### | 100%
# libedit-3.1.20191231 | 121 KB    | ##################################### | 100%
# pooch-1.4.0          | 41 KB     | ##################################### | 100%
# joblib-1.0.1         | 206 KB    | ##################################### | 100%
# libbrotlienc-1.0.9   | 286 KB    | ##################################### | 100%
# dataclasses-0.8      | 7 KB      | ##################################### | 100%
# zipp-3.5.0           | 12 KB     | ##################################### | 100%
# pyopenssl-20.0.1     | 48 KB     | ##################################### | 100%
# ipykernel-5.5.5      | 167 KB    | ##################################### | 100%
# glib-2.68.3          | 449 KB    | ##################################### | 100%
# libevent-2.1.10      | 1.1 MB    | ##################################### | 100%
# expat-2.4.1          | 182 KB    | ##################################### | 100%
# prometheus_client-0. | 46 KB     | ##################################### | 100%
# requests-2.25.1      | 51 KB     | ##################################### | 100%
# freetds-1.1.15       | 2.5 MB    | ##################################### | 100%
# mkl-2020.4           | 215.6 MB  | ##################################### | 100%
# seaborn-0.11.1       | 4 KB      | ##################################### | 100%
# entrypoints-0.3      | 8 KB      | ##################################### | 100%
# ca-certificates-2021 | 136 KB    | ##################################### | 100%
# pyqt-impl-5.12.3     | 5.9 MB    | ##################################### | 100%
# certifi-2021.5.30    | 141 KB    | ##################################### | 100%
# keras-preprocessing- | 34 KB     | ##################################### | 100%
# yarl-1.6.3           | 142 KB    | ##################################### | 100%
# jupyterlab_server-1. | 25 KB     | ##################################### | 100%
# widgetsnbextension-3 | 1.8 MB    | ##################################### | 100%
# sip-4.19.25          | 295 KB    | ##################################### | 100%
# mkl-service-2.3.0    | 54 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: \ b'Exception while loading config file /var/pod/.ws/ax-ext/config/wscloud/jupyter_notebook_config.py\n    Traceback (most recent call last):\n      File "/opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/traitlets/config/application.py", line 737, in _load_config_files\n        config = loader.load_config()\n      File "/opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/traitlets/config/loader.py", line 616, in load_config\n        self._read_file_as_dict()\n      File "/opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/traitlets/config/loader.py", line 648, in _read_file_as_dict\n        exec(compile(f.read(), conf_filename, \'exec\'), namespace, namespace)\n      File "/var/pod/.ws/ax-ext/config/wscloud/jupyter_notebook_config.py", line 17, in <module>\n        from cdsax_jupyter_extensions.ax_log import ax_log_request\n    ModuleNotFoundError: No module named \'cdsax_jupyter_extensions\'\nEnabling notebook extension jupyter-js-widgets/extension...\n      - Validating: \x1bOK\x1b\n'
# done
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-2dd7a0515098> in <module>
#      23 get_ipython().run_line_magic('matplotlib', 'inline')
#      24
# ---> 25 import seaborn as sns
#      26
#      27 print('Libraries imported.')
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/seaborn/__init__.py in <module>
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#       5 from .relational import *  # noqa: F401,F403
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/seaborn/rcmod.py in <module>
#       5 import matplotlib as mpl
#       6 from cycler import cycler
# ----> 7 from . import palettes
#       8
#       9
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/seaborn/palettes.py in <module>
#       7 from .external import husl
#       8
# ----> 9 from .utils import desaturate, get_color_cycle
#      10 from .colors import xkcd_rgb, crayons
#      11
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/seaborn/utils.py in <module>
#       8
#       9 import numpy as np
# ---> 10 from scipy import stats
#      11 import pandas as pd
#      12 import matplotlib as mpl
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/scipy/stats/__init__.py in <module>
#     386
#     387 """
# --> 388 from .stats import *
#     389 from .distributions import *
#     390 from .morestats import *
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/scipy/stats/stats.py in <module>
#     178 import scipy.special as special
#     179 from scipy import linalg
# --> 180 from . import distributions
#     181 from . import mstats_basic
#     182 from ._stats_mstats_common import (_find_repeats, linregress, theilslopes,
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/scipy/stats/distributions.py in <module>
#       6 #       instead of `git blame -Lxxx,+x`.
#       7 #
# ----> 8 from ._distn_infrastructure import (entropy, rv_discrete, rv_continuous,
#       9                                     rv_frozen)
#      10
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py in <module>
#      21
#      22 # for root finding for continuous distribution ppf, and max likelihood estimation
# ---> 23 from scipy import optimize
#      24
#      25 # for functions of continuous distributions (e.g. moments, entropy, cdf)
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/scipy/optimize/__init__.py in <module>
#     386
#     387 from .optimize import *
# --> 388 from ._minimize import *
#     389 from ._root import *
#     390 from ._root_scalar import *
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/scipy/optimize/_minimize.py in <module>
#      25 from ._trustregion_krylov import _minimize_trust_krylov
#      26 from ._trustregion_exact import _minimize_trustregion_exact
# ---> 27 from ._trustregion_constr import _minimize_trustregion_constr
#      28
#      29 # constrained minimization
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/scipy/optimize/_trustregion_constr/__init__.py in <module>
#       2
#       3
# ----> 4 from .minimize_trustregion_constr import _minimize_trustregion_constr
#       5
#       6 __all__ = ['_minimize_trustregion_constr']
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/scipy/optimize/_trustregion_constr/minimize_trustregion_constr.py in <module>
#       3 from scipy.sparse.linalg import LinearOperator
#       4 from .._differentiable_functions import VectorFunction
# ----> 5 from .._constraints import (
#       6     NonlinearConstraint, LinearConstraint, PreparedConstraint, strict_bounds)
#       7 from .._hessian_update_strategy import BFGS
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/scipy/optimize/_constraints.py in <module>
#       6 from .optimize import OptimizeWarning
#       7 from warnings import warn
# ----> 8 from numpy.testing import suppress_warnings
#       9 from scipy.sparse import issparse
#      10
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/numpy/testing/__init__.py in <module>
#       8 from unittest import TestCase
#       9
# ---> 10 from ._private.utils import *
#      11 from ._private import decorators as dec
#      12 from ._private.nosetester import (
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/numpy/testing/_private/utils.py in <module>
#      50 IS_PYPY = platform.python_implementation() == 'PyPy'
#      51 HAS_REFCOUNT = getattr(sys, 'getrefcount', None) is not None
# ---> 52 HAS_LAPACK64 = numpy.linalg.lapack_lite._ilp64
#      53
#      54
#
# AttributeError: module 'numpy.linalg.lapack_lite' has no attribute '_ilp64'

# %% [markdown]
# Needed variables

# %%
# Define Foursquare Credentials and Version

CLIENT_ID = 'DAPHWQEXGCOJM5U3U31N23F1WZIUNQPD5U3YLWXPQI3EYBSO' # your Foursquare ID
CLIENT_SECRET = 'LJF1PIOPWMCNGSRB3H1GE0LT4C44BQACT3RZIYPE144TOHS4' # your Foursquare Secret
VERSION = '20210629' # Foursquare API version

# %%
#Define the functions
def geo_location(address):
    # get geo location of address
    geolocator = Nominatim(user_agent="foursquare_agent")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    return latitude,longitude


def get_venues(lat,lng):
    #set variables
    radius=400
    LIMIT=100
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    # get all the data
    results = requests.get(url).json()
    venue_data=results['response']['groups'][0]['items']
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
        except KeyError:
            pass
    column_names=['ID','Name','Category']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df


def get_venue_details(venue_id):
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    # get all the data
    results = requests.get(url).json()
    print(results)
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_rating=venue_data['rating']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
    except KeyError:
        pass
    column_names=['ID','Name','Likes','Rating','Tips']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df


def get_new_york_data():
    url='https://cocl.us/new_york_dataset'
    resp=requests.get(url).json()
    # all data is present in features label
    features=resp['features']
    # define the dataframe columns
    column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 
    # instantiate the dataframe
    new_york_data = pd.DataFrame(columns=column_names)
    for data in features:
        borough = data['properties']['borough'] 
        neighborhood_name = data['properties']['name']
        neighborhood_latlon = data['geometry']['coordinates']
        neighborhood_lat = neighborhood_latlon[1]
        neighborhood_lon = neighborhood_latlon[0]
        new_york_data = new_york_data.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
    return new_york_data

# %% [markdown]
# Get initial NYC data

# %%
ny_data = get_new_york_data()
ny_data.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/frame.py in _repr_html_(self)
#     732             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#     733             # expected "Union[Union[Union[ExtensionArray, ndarray],
# --> 734             # Index, Series], Sequence[Any]]"
#     735             index = ensure_index(index)  # type: ignore[arg-type]
#     736             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/formats/format.py in to_html(self, buf, encoding, classes, notebook, border)
#     980         string = latex_formatter.to_string()
#     981         return save_to_buffer(string, buf=buf, encoding=encoding)
# --> 982
#     983     def to_html(
#     984         self,
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/formats/html.py in __init__(self, formatter, classes, border, table_id, render_links)
#      66         self.col_space = {
#      67             column: f"{value}px" if isinstance(value, int) else value
# ---> 68             for column, value in self.fmt.col_space.items()
#      69         }
#      70
#
# AttributeError: 'NoneType' object has no attribute 'items'
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
ny_data.shape
# Out:
# (306, 4)

# %% [markdown]
# Data Analysis

# %%
clr = "green"
ny_data.groupby('Borough')['Neighborhood'].count().plot.bar(figsize=(10,5), color=clr)
plt.title('Neighborhoods per Borough: NYC', fontsize = 20)
plt.xlabel('Borough', fontsize = 15)
plt.ylabel('No. Neighborhoods',fontsize = 15)
plt.xticks(rotation = 'horizontal')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-ca217a8524c6> in <module>
#       1 clr = "green"
# ----> 2 ny_data.groupby('Borough')['Neighborhood'].count().plot.bar(figsize=(10,5), color=clr)
#       3 plt.title('Neighborhoods per Borough: NYC', fontsize = 20)
#       4 plt.xlabel('Borough', fontsize = 15)
#       5 plt.ylabel('No. Neighborhoods',fontsize = 15)
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/plotting/_core.py in bar(self, x, y, **kwargs)
#    1001             >>> lines = df.plot.line()
#    1002
# -> 1003         .. plot::
#    1004            :context: close-figs
#    1005
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     765     Returns
#     766     -------
# --> 767     :class:`matplotlib.axes.Axes` or numpy.ndarray of them
#     768         If the backend is not the default matplotlib one, the return value
#     769         will be the object returned by the backend.
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1667             chosen in a way that the hexagons are approximately regular.
#    1668             Alternatively, gridsize can be a tuple with two elements
# -> 1669             specifying the number of hexagons in the x-direction and the
#    1670             y-direction.
#    1671         **kwargs
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.

# %% [markdown]
# Japanese restaurants in each neighborhood and borough
# Graph the results

# %%
# queens has most neighborhoods
# prepare neighborhood list that contains japanese restaurants
column_names=['Borough', 'Neighborhood', 'ID','Name']
japanese_rest_ny=pd.DataFrame(columns=column_names)
count=1
for row in ny_data.values.tolist():
    Borough, Neighborhood, Latitude, Longitude=row
    venues = get_venues(Latitude,Longitude)
    japanese_restaurants=venues[venues['Category']=='Japanese Restaurant']   
    print('(',count,'/',len(ny_data),')','Japanese Restaurants in '+Neighborhood+', '+Borough+':'+str(len(japanese_restaurants)))
    print(row)
    for resturant_detail in japanese_restaurants.values.tolist():
        id, name , category=resturant_detail
        japanese_rest_ny = japanese_rest_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name
                                               }, ignore_index=True)
    count+=1
# Out:
# ( 1 / 306 ) Japanese Restaurants in Wakefield, Bronx:0
# ['Bronx', 'Wakefield', 40.89470517661, -73.84720052054902]
# ( 2 / 306 ) Japanese Restaurants in Co-op City, Bronx:0
# ['Bronx', 'Co-op City', 40.87429419303012, -73.82993910812398]
# ( 3 / 306 ) Japanese Restaurants in Eastchester, Bronx:0
# ['Bronx', 'Eastchester', 40.887555677350775, -73.82780644716412]
# ( 4 / 306 ) Japanese Restaurants in Fieldston, Bronx:0
# ['Bronx', 'Fieldston', 40.89543742690383, -73.90564259591682]
# ( 5 / 306 ) Japanese Restaurants in Riverdale, Bronx:0
# ['Bronx', 'Riverdale', 40.890834493891305, -73.9125854610857]
# ( 6 / 306 ) Japanese Restaurants in Kingsbridge, Bronx:0
# ['Bronx', 'Kingsbridge', 40.88168737120521, -73.90281798724604]
# ( 7 / 306 ) Japanese Restaurants in Marble Hill, Manhattan:0
# ['Manhattan', 'Marble Hill', 40.87655077879964, -73.91065965862981]
# ( 8 / 306 ) Japanese Restaurants in Woodlawn, Bronx:0
# ['Bronx', 'Woodlawn', 40.89827261213805, -73.86731496814176]
# ( 9 / 306 ) Japanese Restaurants in Norwood, Bronx:0
# ['Bronx', 'Norwood', 40.87722415599446, -73.8793907395681]
# ( 10 / 306 ) Japanese Restaurants in Williamsbridge, Bronx:0
# ['Bronx', 'Williamsbridge', 40.88103887819211, -73.85744642974207]
# ( 11 / 306 ) Japanese Restaurants in Baychester, Bronx:0
# ['Bronx', 'Baychester', 40.866858107252696, -73.83579759808117]
# ( 12 / 306 ) Japanese Restaurants in Pelham Parkway, Bronx:0
# ['Bronx', 'Pelham Parkway', 40.85741349808865, -73.85475564017999]
# ( 13 / 306 ) Japanese Restaurants in City Island, Bronx:0
# ['Bronx', 'City Island', 40.84724670491813, -73.78648845267413]
# ( 14 / 306 ) Japanese Restaurants in Bedford Park, Bronx:0
# ['Bronx', 'Bedford Park', 40.870185164975325, -73.8855121841913]
# ( 15 / 306 ) Japanese Restaurants in University Heights, Bronx:0
# ['Bronx', 'University Heights', 40.85572707719664, -73.9104159619131]
# ( 16 / 306 ) Japanese Restaurants in Morris Heights, Bronx:0
# ['Bronx', 'Morris Heights', 40.84789792606271, -73.91967159119565]
# ( 17 / 306 ) Japanese Restaurants in Fordham, Bronx:0
# ['Bronx', 'Fordham', 40.86099679638654, -73.89642655981623]
# ( 18 / 306 ) Japanese Restaurants in East Tremont, Bronx:0
# ['Bronx', 'East Tremont', 40.84269615786053, -73.88735617532338]
# ( 19 / 306 ) Japanese Restaurants in West Farms, Bronx:0
# ['Bronx', 'West Farms', 40.83947505672653, -73.87774474910545]
# ( 20 / 306 ) Japanese Restaurants in High  Bridge, Bronx:0
# ['Bronx', 'High  Bridge', 40.836623010706056, -73.9261020935813]
# ( 21 / 306 ) Japanese Restaurants in Melrose, Bronx:0
# ['Bronx', 'Melrose', 40.819754370594936, -73.90942160757436]
# ( 22 / 306 ) Japanese Restaurants in Mott Haven, Bronx:0
# ['Bronx', 'Mott Haven', 40.80623874935177, -73.91609987487575]
# ( 23 / 306 ) Japanese Restaurants in Port Morris, Bronx:0
# ['Bronx', 'Port Morris', 40.801663627756206, -73.91322139386135]
# ( 24 / 306 ) Japanese Restaurants in Longwood, Bronx:0
# ['Bronx', 'Longwood', 40.81509904545822, -73.8957882009446]
# ( 25 / 306 ) Japanese Restaurants in Hunts Point, Bronx:0
# ['Bronx', 'Hunts Point', 40.80972987938709, -73.88331505955291]
# ( 26 / 306 ) Japanese Restaurants in Morrisania, Bronx:0
# ['Bronx', 'Morrisania', 40.82359198585534, -73.90150648943059]
# ( 27 / 306 ) Japanese Restaurants in Soundview, Bronx:0
# ['Bronx', 'Soundview', 40.821012197914015, -73.86574609554924]
# ( 28 / 306 ) Japanese Restaurants in Clason Point, Bronx:0
# ['Bronx', 'Clason Point', 40.80655112003589, -73.85414416189266]
# ( 29 / 306 ) Japanese Restaurants in Throgs Neck, Bronx:0
# ['Bronx', 'Throgs Neck', 40.81510925804005, -73.81635002158441]
# ( 30 / 306 ) Japanese Restaurants in Country Club, Bronx:0
# ['Bronx', 'Country Club', 40.844245936947374, -73.8240992675385]
# ( 31 / 306 ) Japanese Restaurants in Parkchester, Bronx:0
# ['Bronx', 'Parkchester', 40.837937822267286, -73.85600310535783]
# ( 32 / 306 ) Japanese Restaurants in Westchester Square, Bronx:0
# ['Bronx', 'Westchester Square', 40.8406194964327, -73.84219407604444]
# ( 33 / 306 ) Japanese Restaurants in Van Nest, Bronx:0
# ['Bronx', 'Van Nest', 40.84360847124718, -73.8662991807561]
# ( 34 / 306 ) Japanese Restaurants in Morris Park, Bronx:0
# ['Bronx', 'Morris Park', 40.847549063536334, -73.85040178030421]
# ( 35 / 306 ) Japanese Restaurants in Belmont, Bronx:0
# ['Bronx', 'Belmont', 40.85727710073895, -73.88845196134804]
# ( 36 / 306 ) Japanese Restaurants in Spuyten Duyvil, Bronx:0
# ['Bronx', 'Spuyten Duyvil', 40.88139497727086, -73.91719048210393]
# ( 37 / 306 ) Japanese Restaurants in North Riverdale, Bronx:0
# ['Bronx', 'North Riverdale', 40.90854282950666, -73.90453054908927]
# ( 38 / 306 ) Japanese Restaurants in Pelham Bay, Bronx:0
# ['Bronx', 'Pelham Bay', 40.85064140940335, -73.8320737824047]
# ( 39 / 306 ) Japanese Restaurants in Schuylerville, Bronx:0
# ['Bronx', 'Schuylerville', 40.82657951686922, -73.82620275994073]
# ( 40 / 306 ) Japanese Restaurants in Edgewater Park, Bronx:0
# ['Bronx', 'Edgewater Park', 40.821986118163494, -73.81388514428619]
# ( 41 / 306 ) Japanese Restaurants in Castle Hill, Bronx:0
# ['Bronx', 'Castle Hill', 40.819014376988314, -73.84802729582735]
# ( 42 / 306 ) Japanese Restaurants in Olinville, Bronx:0
# ['Bronx', 'Olinville', 40.87137078192371, -73.86332361652777]
# ( 43 / 306 ) Japanese Restaurants in Pelham Gardens, Bronx:0
# ['Bronx', 'Pelham Gardens', 40.86296562477998, -73.84161194831223]
# ( 44 / 306 ) Japanese Restaurants in Concourse, Bronx:0
# ['Bronx', 'Concourse', 40.83428380733851, -73.91558941773444]
# ( 45 / 306 ) Japanese Restaurants in Unionport, Bronx:0
# ['Bronx', 'Unionport', 40.82977429787161, -73.85053524451935]
# ( 46 / 306 ) Japanese Restaurants in Edenwald, Bronx:0
# ['Bronx', 'Edenwald', 40.88456130303732, -73.84808271877168]
# ( 47 / 306 ) Japanese Restaurants in Bay Ridge, Brooklyn:0
# ['Brooklyn', 'Bay Ridge', 40.625801065010656, -74.03062069353813]
# ( 48 / 306 ) Japanese Restaurants in Bensonhurst, Brooklyn:0
# ['Brooklyn', 'Bensonhurst', 40.61100890202044, -73.99517998380729]
# ( 49 / 306 ) Japanese Restaurants in Sunset Park, Brooklyn:0
# ['Brooklyn', 'Sunset Park', 40.64510294925429, -74.01031618527784]
# ( 50 / 306 ) Japanese Restaurants in Greenpoint, Brooklyn:0
# ['Brooklyn', 'Greenpoint', 40.7302009848647, -73.95424093127393]
# ( 51 / 306 ) Japanese Restaurants in Gravesend, Brooklyn:0
# ['Brooklyn', 'Gravesend', 40.59526001306593, -73.97347087708445]
# ( 52 / 306 ) Japanese Restaurants in Brighton Beach, Brooklyn:0
# ['Brooklyn', 'Brighton Beach', 40.57682506566604, -73.96509448785336]
# ( 53 / 306 ) Japanese Restaurants in Sheepshead Bay, Brooklyn:0
# ['Brooklyn', 'Sheepshead Bay', 40.58689012678384, -73.94318640482979]
# ( 54 / 306 ) Japanese Restaurants in Manhattan Terrace, Brooklyn:0
# ['Brooklyn', 'Manhattan Terrace', 40.61443251335098, -73.95743840559939]
# ( 55 / 306 ) Japanese Restaurants in Flatbush, Brooklyn:0
# ['Brooklyn', 'Flatbush', 40.63632589026677, -73.95840106533903]
# ( 56 / 306 ) Japanese Restaurants in Crown Heights, Brooklyn:0
# ['Brooklyn', 'Crown Heights', 40.67082917695294, -73.94329119073582]
# ( 57 / 306 ) Japanese Restaurants in East Flatbush, Brooklyn:0
# ['Brooklyn', 'East Flatbush', 40.64171776668961, -73.93610256185836]
# ( 58 / 306 ) Japanese Restaurants in Kensington, Brooklyn:1
# ['Brooklyn', 'Kensington', 40.642381958003526, -73.98042110559474]
# ( 59 / 306 ) Japanese Restaurants in Windsor Terrace, Brooklyn:0
# ['Brooklyn', 'Windsor Terrace', 40.65694583575104, -73.98007340430172]
# ( 60 / 306 ) Japanese Restaurants in Prospect Heights, Brooklyn:1
# ['Brooklyn', 'Prospect Heights', 40.676822262254724, -73.9648592426269]
# ( 61 / 306 ) Japanese Restaurants in Brownsville, Brooklyn:0
# ['Brooklyn', 'Brownsville', 40.66394994339755, -73.91023536176607]
# ( 62 / 306 ) Japanese Restaurants in Williamsburg, Brooklyn:1
# ['Brooklyn', 'Williamsburg', 40.70714439344251, -73.95811529220927]
# ( 63 / 306 ) Japanese Restaurants in Bushwick, Brooklyn:0
# ['Brooklyn', 'Bushwick', 40.69811611017901, -73.92525797487045]
# ( 64 / 306 ) Japanese Restaurants in Bedford Stuyvesant, Brooklyn:1
# ['Brooklyn', 'Bedford Stuyvesant', 40.687231607720456, -73.94178488690297]
# ( 65 / 306 ) Japanese Restaurants in Brooklyn Heights, Brooklyn:1
# ['Brooklyn', 'Brooklyn Heights', 40.695863722724084, -73.99378225496424]
# ( 66 / 306 ) Japanese Restaurants in Cobble Hill, Brooklyn:1
# ['Brooklyn', 'Cobble Hill', 40.687919722485574, -73.99856139218463]
# ( 67 / 306 ) Japanese Restaurants in Carroll Gardens, Brooklyn:1
# ['Brooklyn', 'Carroll Gardens', 40.680540231076485, -73.99465372828006]
# ( 68 / 306 ) Japanese Restaurants in Red Hook, Brooklyn:0
# ['Brooklyn', 'Red Hook', 40.676253230250886, -74.0127589747356]
# ( 69 / 306 ) Japanese Restaurants in Gowanus, Brooklyn:0
# ['Brooklyn', 'Gowanus', 40.673931143187154, -73.99444087145339]
# ( 70 / 306 ) Japanese Restaurants in Fort Greene, Brooklyn:0
# ['Brooklyn', 'Fort Greene', 40.68852726018977, -73.97290574369092]
# ( 71 / 306 ) Japanese Restaurants in Park Slope, Brooklyn:2
# ['Brooklyn', 'Park Slope', 40.67232052268197, -73.97705030183924]
# ( 72 / 306 ) Japanese Restaurants in Cypress Hills, Brooklyn:0
# ['Brooklyn', 'Cypress Hills', 40.68239101144211, -73.87661596457296]
# ( 73 / 306 ) Japanese Restaurants in East New York, Brooklyn:0
# ['Brooklyn', 'East New York', 40.669925700847045, -73.88069863917366]
# ( 74 / 306 ) Japanese Restaurants in Starrett City, Brooklyn:0
# ['Brooklyn', 'Starrett City', 40.64758905230874, -73.87936970045875]
# ( 75 / 306 ) Japanese Restaurants in Canarsie, Brooklyn:0
# ['Brooklyn', 'Canarsie', 40.63556432797428, -73.90209269778966]
# ( 76 / 306 ) Japanese Restaurants in Flatlands, Brooklyn:0
# ['Brooklyn', 'Flatlands', 40.630446043757466, -73.92911302644674]
# ( 77 / 306 ) Japanese Restaurants in Mill Island, Brooklyn:0
# ['Brooklyn', 'Mill Island', 40.606336421685626, -73.90818571777423]
# ( 78 / 306 ) Japanese Restaurants in Manhattan Beach, Brooklyn:0
# ['Brooklyn', 'Manhattan Beach', 40.57791350308657, -73.94353722891886]
# ( 79 / 306 ) Japanese Restaurants in Coney Island, Brooklyn:0
# ['Brooklyn', 'Coney Island', 40.57429256471601, -73.98868295821637]
# ( 80 / 306 ) Japanese Restaurants in Bath Beach, Brooklyn:0
# ['Brooklyn', 'Bath Beach', 40.59951870282238, -73.99875221443519]
# ( 81 / 306 ) Japanese Restaurants in Borough Park, Brooklyn:0
# ['Brooklyn', 'Borough Park', 40.633130512758015, -73.99049823044811]
# ( 82 / 306 ) Japanese Restaurants in Dyker Heights, Brooklyn:0
# ['Brooklyn', 'Dyker Heights', 40.619219457722636, -74.01931375636022]
# ( 83 / 306 ) Japanese Restaurants in Gerritsen Beach, Brooklyn:0
# ['Brooklyn', 'Gerritsen Beach', 40.590848433902046, -73.93010170691196]
# ( 84 / 306 ) Japanese Restaurants in Marine Park, Brooklyn:0
# ['Brooklyn', 'Marine Park', 40.609747779894604, -73.93134404108497]
# ( 85 / 306 ) Japanese Restaurants in Clinton Hill, Brooklyn:1
# ['Brooklyn', 'Clinton Hill', 40.693229421881504, -73.96784306216367]
# ( 86 / 306 ) Japanese Restaurants in Sea Gate, Brooklyn:0
# ['Brooklyn', 'Sea Gate', 40.57637537890224, -74.0078731120024]
# ( 87 / 306 ) Japanese Restaurants in Downtown, Brooklyn:1
# ['Brooklyn', 'Downtown', 40.69084402109802, -73.98346337431099]
# ( 88 / 306 ) Japanese Restaurants in Boerum Hill, Brooklyn:1
# ['Brooklyn', 'Boerum Hill', 40.685682912091444, -73.98374824115798]
# ( 89 / 306 ) Japanese Restaurants in Prospect Lefferts Gardens, Brooklyn:0
# ['Brooklyn', 'Prospect Lefferts Gardens', 40.658420017469815, -73.95489867077713]
# ( 90 / 306 ) Japanese Restaurants in Ocean Hill, Brooklyn:0
# ['Brooklyn', 'Ocean Hill', 40.678402554795355, -73.91306831787395]
# ( 91 / 306 ) Japanese Restaurants in City Line, Brooklyn:0
# ['Brooklyn', 'City Line', 40.67856995727479, -73.86797598081334]
# ( 92 / 306 ) Japanese Restaurants in Bergen Beach, Brooklyn:0
# ['Brooklyn', 'Bergen Beach', 40.61514955045308, -73.89855633630317]
# ( 93 / 306 ) Japanese Restaurants in Midwood, Brooklyn:0
# ['Brooklyn', 'Midwood', 40.62559589869843, -73.95759523489838]
# ( 94 / 306 ) Japanese Restaurants in Prospect Park South, Brooklyn:0
# ['Brooklyn', 'Prospect Park South', 40.647008603185185, -73.96261316716048]
# ( 95 / 306 ) Japanese Restaurants in Georgetown, Brooklyn:0
# ['Brooklyn', 'Georgetown', 40.62384524478419, -73.91607483951324]
# ( 96 / 306 ) Japanese Restaurants in East Williamsburg, Brooklyn:0
# ['Brooklyn', 'East Williamsburg', 40.70849241041548, -73.93885815269195]
# ( 97 / 306 ) Japanese Restaurants in North Side, Brooklyn:1
# ['Brooklyn', 'North Side', 40.714822906532014, -73.95880857587582]
# ( 98 / 306 ) Japanese Restaurants in South Side, Brooklyn:1
# ['Brooklyn', 'South Side', 40.71086147265064, -73.95800095153331]
# ( 99 / 306 ) Japanese Restaurants in Ocean Parkway, Brooklyn:0
# ['Brooklyn', 'Ocean Parkway', 40.61305976667942, -73.96836678035541]
# ( 100 / 306 ) Japanese Restaurants in Fort Hamilton, Brooklyn:1
# ['Brooklyn', 'Fort Hamilton', 40.61476812694226, -74.03197914537984]
# ( 101 / 306 ) Japanese Restaurants in Chinatown, Manhattan:0
# ['Manhattan', 'Chinatown', 40.71561842231432, -73.99427936255978]
# ( 102 / 306 ) Japanese Restaurants in Washington Heights, Manhattan:0
# ['Manhattan', 'Washington Heights', 40.85190252555305, -73.93690027985234]
# ( 103 / 306 ) Japanese Restaurants in Inwood, Manhattan:0
# ['Manhattan', 'Inwood', 40.86768396449915, -73.92121042203897]
# ( 104 / 306 ) Japanese Restaurants in Hamilton Heights, Manhattan:1
# ['Manhattan', 'Hamilton Heights', 40.823604284811935, -73.94968791883366]
# ( 105 / 306 ) Japanese Restaurants in Manhattanville, Manhattan:0
# ['Manhattan', 'Manhattanville', 40.8169344294978, -73.9573853935188]
# ( 106 / 306 ) Japanese Restaurants in Central Harlem, Manhattan:0
# ['Manhattan', 'Central Harlem', 40.81597606742414, -73.94321112603905]
# ( 107 / 306 ) Japanese Restaurants in East Harlem, Manhattan:0
# ['Manhattan', 'East Harlem', 40.79224946663033, -73.94418223148524]
# ( 108 / 306 ) Japanese Restaurants in Upper East Side, Manhattan:1
# ['Manhattan', 'Upper East Side', 40.775638573301805, -73.96050763135]
# ( 109 / 306 ) Japanese Restaurants in Yorkville, Manhattan:1
# ['Manhattan', 'Yorkville', 40.775929849884875, -73.94711784471826]
# ( 110 / 306 ) Japanese Restaurants in Lenox Hill, Manhattan:1
# ['Manhattan', 'Lenox Hill', 40.76811265828733, -73.9588596881376]
# ( 111 / 306 ) Japanese Restaurants in Roosevelt Island, Manhattan:0
# ['Manhattan', 'Roosevelt Island', 40.76215960576283, -73.94916769227953]
# ( 112 / 306 ) Japanese Restaurants in Upper West Side, Manhattan:0
# ['Manhattan', 'Upper West Side', 40.787657998534854, -73.97705923630603]
# ( 113 / 306 ) Japanese Restaurants in Lincoln Square, Manhattan:0
# ['Manhattan', 'Lincoln Square', 40.77352888942166, -73.98533777001262]
# ( 114 / 306 ) Japanese Restaurants in Clinton, Manhattan:0
# ['Manhattan', 'Clinton', 40.75910089146212, -73.99611936309479]
# ( 115 / 306 ) Japanese Restaurants in Midtown, Manhattan:2
# ['Manhattan', 'Midtown', 40.75469110270623, -73.98166882730304]
# ( 116 / 306 ) Japanese Restaurants in Murray Hill, Manhattan:4
# ['Manhattan', 'Murray Hill', 40.748303077252174, -73.97833207924127]
# ( 117 / 306 ) Japanese Restaurants in Chelsea, Manhattan:1
# ['Manhattan', 'Chelsea', 40.744034706747975, -74.00311633472813]
# ( 118 / 306 ) Japanese Restaurants in Greenwich Village, Manhattan:1
# ['Manhattan', 'Greenwich Village', 40.72693288536128, -73.99991402945902]
# ( 119 / 306 ) Japanese Restaurants in East Village, Manhattan:2
# ['Manhattan', 'East Village', 40.727846777270244, -73.98222616506416]
# ( 120 / 306 ) Japanese Restaurants in Lower East Side, Manhattan:0
# ['Manhattan', 'Lower East Side', 40.71780674892765, -73.98089031999291]
# ( 121 / 306 ) Japanese Restaurants in Tribeca, Manhattan:0
# ['Manhattan', 'Tribeca', 40.721521967443216, -74.01068328559087]
# ( 122 / 306 ) Japanese Restaurants in Little Italy, Manhattan:0
# ['Manhattan', 'Little Italy', 40.71932379395907, -73.99730467208073]
# ( 123 / 306 ) Japanese Restaurants in Soho, Manhattan:1
# ['Manhattan', 'Soho', 40.72218384131794, -74.00065666959759]
# ( 124 / 306 ) Japanese Restaurants in West Village, Manhattan:1
# ['Manhattan', 'West Village', 40.73443393572434, -74.00617998126812]
# ( 125 / 306 ) Japanese Restaurants in Manhattan Valley, Manhattan:0
# ['Manhattan', 'Manhattan Valley', 40.797307041702865, -73.96428617740655]
# ( 126 / 306 ) Japanese Restaurants in Morningside Heights, Manhattan:0
# ['Manhattan', 'Morningside Heights', 40.807999738165826, -73.96389627905332]
# ( 127 / 306 ) Japanese Restaurants in Gramercy, Manhattan:0
# ['Manhattan', 'Gramercy', 40.737209832715, -73.98137594833541]
# ( 128 / 306 ) Japanese Restaurants in Battery Park City, Manhattan:0
# ['Manhattan', 'Battery Park City', 40.71193198394565, -74.01686930508617]
# ( 129 / 306 ) Japanese Restaurants in Financial District, Manhattan:0
# ['Manhattan', 'Financial District', 40.70710710727048, -74.0106654452127]
# ( 130 / 306 ) Japanese Restaurants in Astoria, Queens:0
# ['Queens', 'Astoria', 40.76850859335492, -73.91565374304234]
# ( 131 / 306 ) Japanese Restaurants in Woodside, Queens:1
# ['Queens', 'Woodside', 40.74634908860222, -73.90184166838284]
# ( 132 / 306 ) Japanese Restaurants in Jackson Heights, Queens:0
# ['Queens', 'Jackson Heights', 40.75198138007367, -73.88282109164365]
# ( 133 / 306 ) Japanese Restaurants in Elmhurst, Queens:0
# ['Queens', 'Elmhurst', 40.744048505122024, -73.88165622288388]
# ( 134 / 306 ) Japanese Restaurants in Howard Beach, Queens:1
# ['Queens', 'Howard Beach', 40.65422527738487, -73.8381376460028]
# ( 135 / 306 ) Japanese Restaurants in Corona, Queens:0
# ['Queens', 'Corona', 40.74238175015667, -73.85682497345258]
# ( 136 / 306 ) Japanese Restaurants in Forest Hills, Queens:0
# ['Queens', 'Forest Hills', 40.72526378216503, -73.84447500788983]
# ( 137 / 306 ) Japanese Restaurants in Kew Gardens, Queens:0
# ['Queens', 'Kew Gardens', 40.7051790354148, -73.82981905825703]
# ( 138 / 306 ) Japanese Restaurants in Richmond Hill, Queens:0
# ['Queens', 'Richmond Hill', 40.69794731471763, -73.83183321446887]
# ( 139 / 306 ) Japanese Restaurants in Flushing, Queens:0
# ['Queens', 'Flushing', 40.76445419697846, -73.83177300329582]
# ( 140 / 306 ) Japanese Restaurants in Long Island City, Queens:0
# ['Queens', 'Long Island City', 40.75021734610528, -73.93920223915505]
# ( 141 / 306 ) Japanese Restaurants in Sunnyside, Queens:0
# ['Queens', 'Sunnyside', 40.74017628351924, -73.92691617561577]
# ( 142 / 306 ) Japanese Restaurants in East Elmhurst, Queens:0
# ['Queens', 'East Elmhurst', 40.76407323883091, -73.86704147658772]
# ( 143 / 306 ) Japanese Restaurants in Maspeth, Queens:0
# ['Queens', 'Maspeth', 40.725427374093606, -73.89621713626859]
# ( 144 / 306 ) Japanese Restaurants in Ridgewood, Queens:0
# ['Queens', 'Ridgewood', 40.70832315613858, -73.90143517559589]
# ( 145 / 306 ) Japanese Restaurants in Glendale, Queens:0
# ['Queens', 'Glendale', 40.70276242967838, -73.87074167435605]
# ( 146 / 306 ) Japanese Restaurants in Rego Park, Queens:2
# ['Queens', 'Rego Park', 40.72897409480735, -73.8578268690537]
# ( 147 / 306 ) Japanese Restaurants in Woodhaven, Queens:0
# ['Queens', 'Woodhaven', 40.68988687915789, -73.8581104655432]
# ( 148 / 306 ) Japanese Restaurants in Ozone Park, Queens:0
# ['Queens', 'Ozone Park', 40.680708468265415, -73.84320266173447]
# ( 149 / 306 ) Japanese Restaurants in South Ozone Park, Queens:0
# ['Queens', 'South Ozone Park', 40.66854957767195, -73.80986478649041]
# ( 150 / 306 ) Japanese Restaurants in College Point, Queens:0
# ['Queens', 'College Point', 40.784902749260205, -73.84304528896125]
# ( 151 / 306 ) Japanese Restaurants in Whitestone, Queens:0
# ['Queens', 'Whitestone', 40.78129076602694, -73.81420216610863]
# ( 152 / 306 ) Japanese Restaurants in Bayside, Queens:0
# ['Queens', 'Bayside', 40.76604063281064, -73.7742736306867]
# ( 153 / 306 ) Japanese Restaurants in Auburndale, Queens:0
# ['Queens', 'Auburndale', 40.76172954903262, -73.79176243728061]
# ( 154 / 306 ) Japanese Restaurants in Little Neck, Queens:2
# ['Queens', 'Little Neck', 40.7708261928267, -73.7388977558074]
# ( 155 / 306 ) Japanese Restaurants in Douglaston, Queens:0
# ['Queens', 'Douglaston', 40.76684609790763, -73.7424982072733]
# ( 156 / 306 ) Japanese Restaurants in Glen Oaks, Queens:0
# ['Queens', 'Glen Oaks', 40.74944079974332, -73.71548118999145]
# ( 157 / 306 ) Japanese Restaurants in Bellerose, Queens:0
# ['Queens', 'Bellerose', 40.72857318176675, -73.72012814826903]
# ( 158 / 306 ) Japanese Restaurants in Kew Gardens Hills, Queens:0
# ['Queens', 'Kew Gardens Hills', 40.722578244228046, -73.82087764933566]
# ( 159 / 306 ) Japanese Restaurants in Fresh Meadows, Queens:0
# ['Queens', 'Fresh Meadows', 40.7343944653313, -73.78271337003264]
# ( 160 / 306 ) Japanese Restaurants in Briarwood, Queens:0
# ['Queens', 'Briarwood', 40.71093547252271, -73.81174822458634]
# ( 161 / 306 ) Japanese Restaurants in Jamaica Center, Queens:1
# ['Queens', 'Jamaica Center', 40.70465736068717, -73.79690165888289]
# ( 162 / 306 ) Japanese Restaurants in Oakland Gardens, Queens:0
# ['Queens', 'Oakland Gardens', 40.74561857141855, -73.75494976234332]
# ( 163 / 306 ) Japanese Restaurants in Queens Village, Queens:0
# ['Queens', 'Queens Village', 40.718893092167356, -73.73871484578424]
# ( 164 / 306 ) Japanese Restaurants in Hollis, Queens:0
# ['Queens', 'Hollis', 40.71124344191904, -73.75925009335594]
# ( 165 / 306 ) Japanese Restaurants in South Jamaica, Queens:0
# ['Queens', 'South Jamaica', 40.696911253789885, -73.7904261313554]
# ( 166 / 306 ) Japanese Restaurants in St. Albans, Queens:0
# ['Queens', 'St. Albans', 40.69444538522359, -73.75867603727717]
# ( 167 / 306 ) Japanese Restaurants in Rochdale, Queens:0
# ['Queens', 'Rochdale', 40.67521139591733, -73.77258787620906]
# ( 168 / 306 ) Japanese Restaurants in Springfield Gardens, Queens:0
# ['Queens', 'Springfield Gardens', 40.666230490368584, -73.76042092682287]
# ( 169 / 306 ) Japanese Restaurants in Cambria Heights, Queens:0
# ['Queens', 'Cambria Heights', 40.692774639160845, -73.73526873708026]
# ( 170 / 306 ) Japanese Restaurants in Rosedale, Queens:0
# ['Queens', 'Rosedale', 40.659816433428084, -73.73526079428278]
# ( 171 / 306 ) Japanese Restaurants in Far Rockaway, Queens:0
# ['Queens', 'Far Rockaway', 40.603134432500894, -73.75497968043872]
# ( 172 / 306 ) Japanese Restaurants in Broad Channel, Queens:0
# ['Queens', 'Broad Channel', 40.60302658351238, -73.8200548911032]
# ( 173 / 306 ) Japanese Restaurants in Breezy Point, Queens:0
# ['Queens', 'Breezy Point', 40.55740128845452, -73.92551196994168]
# ( 174 / 306 ) Japanese Restaurants in Steinway, Queens:0
# ['Queens', 'Steinway', 40.775923015642896, -73.90228960391673]
# ( 175 / 306 ) Japanese Restaurants in Beechhurst, Queens:0
# ['Queens', 'Beechhurst', 40.79278140360048, -73.80436451720988]
# ( 176 / 306 ) Japanese Restaurants in Bay Terrace, Queens:0
# ['Queens', 'Bay Terrace', 40.782842806245554, -73.7768022262158]
# ( 177 / 306 ) Japanese Restaurants in Edgemere, Queens:0
# ['Queens', 'Edgemere', 40.595641807368494, -73.77613282391705]
# ( 178 / 306 ) Japanese Restaurants in Arverne, Queens:0
# ['Queens', 'Arverne', 40.58914394372971, -73.79199233136943]
# ( 179 / 306 ) Japanese Restaurants in Rockaway Beach, Queens:0
# ['Queens', 'Rockaway Beach', 40.582801696845586, -73.82236121088751]
# ( 180 / 306 ) Japanese Restaurants in Neponsit, Queens:0
# ['Queens', 'Neponsit', 40.572036730217015, -73.85754672410827]
# ( 181 / 306 ) Japanese Restaurants in Murray Hill, Queens:1
# ['Queens', 'Murray Hill', 40.764126122614066, -73.81276269135866]
# ( 182 / 306 ) Japanese Restaurants in Floral Park, Queens:0
# ['Queens', 'Floral Park', 40.741378421945434, -73.70884705889246]
# ( 183 / 306 ) Japanese Restaurants in Holliswood, Queens:0
# ['Queens', 'Holliswood', 40.7209572076444, -73.76714166714729]
# ( 184 / 306 ) Japanese Restaurants in Jamaica Estates, Queens:0
# ['Queens', 'Jamaica Estates', 40.71680483014613, -73.7872269693666]
# ( 185 / 306 ) Japanese Restaurants in Queensboro Hill, Queens:0
# ['Queens', 'Queensboro Hill', 40.7445723092867, -73.82580915110559]
# ( 186 / 306 ) Japanese Restaurants in Hillcrest, Queens:0
# ['Queens', 'Hillcrest', 40.723824901829204, -73.79760300912672]
# ( 187 / 306 ) Japanese Restaurants in Ravenswood, Queens:0
# ['Queens', 'Ravenswood', 40.761704526054146, -73.93157506072878]
# ( 188 / 306 ) Japanese Restaurants in Lindenwood, Queens:1
# ['Queens', 'Lindenwood', 40.66391841925139, -73.84963782402441]
# ( 189 / 306 ) Japanese Restaurants in Laurelton, Queens:0
# ['Queens', 'Laurelton', 40.66788389660247, -73.74025607989822]
# ( 190 / 306 ) Japanese Restaurants in Lefrak City, Queens:0
# ['Queens', 'Lefrak City', 40.736074570830795, -73.8625247141374]
# ( 191 / 306 ) Japanese Restaurants in Belle Harbor, Queens:0
# ['Queens', 'Belle Harbor', 40.57615556543109, -73.8540175039252]
# ( 192 / 306 ) Japanese Restaurants in Rockaway Park, Queens:1
# ['Queens', 'Rockaway Park', 40.58034295646131, -73.84153370226186]
# ( 193 / 306 ) Japanese Restaurants in Somerville, Queens:0
# ['Queens', 'Somerville', 40.59771061565768, -73.79664750844047]
# ( 194 / 306 ) Japanese Restaurants in Brookville, Queens:0
# ['Queens', 'Brookville', 40.66000322733613, -73.75175310731153]
# ( 195 / 306 ) Japanese Restaurants in Bellaire, Queens:0
# ['Queens', 'Bellaire', 40.73301404027834, -73.73889198912481]
# ( 196 / 306 ) Japanese Restaurants in North Corona, Queens:0
# ['Queens', 'North Corona', 40.7540709990489, -73.85751790676447]
# ( 197 / 306 ) Japanese Restaurants in Forest Hills Gardens, Queens:0
# ['Queens', 'Forest Hills Gardens', 40.7146110815117, -73.8410221123401]
# ( 198 / 306 ) Japanese Restaurants in St. George, Staten Island:0
# ['Staten Island', 'St. George', 40.6449815710044, -74.07935312512797]
# ( 199 / 306 ) Japanese Restaurants in New Brighton, Staten Island:0
# ['Staten Island', 'New Brighton', 40.64061455913511, -74.08701650516625]
# ( 200 / 306 ) Japanese Restaurants in Stapleton, Staten Island:0
# ['Staten Island', 'Stapleton', 40.62692762538176, -74.07790192660066]
# ( 201 / 306 ) Japanese Restaurants in Rosebank, Staten Island:0
# ['Staten Island', 'Rosebank', 40.61530494652761, -74.06980526716141]
# ( 202 / 306 ) Japanese Restaurants in West Brighton, Staten Island:1
# ['Staten Island', 'West Brighton', 40.63187892654607, -74.1071817826561]
# ( 203 / 306 ) Japanese Restaurants in Grymes Hill, Staten Island:0
# ['Staten Island', 'Grymes Hill', 40.624184791313006, -74.08724819983729]
# ( 204 / 306 ) Japanese Restaurants in Todt Hill, Staten Island:0
# ['Staten Island', 'Todt Hill', 40.59706851814673, -74.1113288180088]
# ( 205 / 306 ) Japanese Restaurants in South Beach, Staten Island:0
# ['Staten Island', 'South Beach', 40.58024741350956, -74.0795529253982]
# ( 206 / 306 ) Japanese Restaurants in Port Richmond, Staten Island:0
# ['Staten Island', 'Port Richmond', 40.63366930554365, -74.12943426797008]
# ( 207 / 306 ) Japanese Restaurants in Mariner's Harbor, Staten Island:0
# ['Staten Island', "Mariner's Harbor", 40.632546390481124, -74.15008537046981]
# ( 208 / 306 ) Japanese Restaurants in Port Ivory, Staten Island:0
# ['Staten Island', 'Port Ivory', 40.63968297845542, -74.17464532993542]
# ( 209 / 306 ) Japanese Restaurants in Castleton Corners, Staten Island:1
# ['Staten Island', 'Castleton Corners', 40.61333593766742, -74.11918058534842]
# ( 210 / 306 ) Japanese Restaurants in New Springville, Staten Island:0
# ['Staten Island', 'New Springville', 40.594252379161695, -74.16496031329827]
# ( 211 / 306 ) Japanese Restaurants in Travis, Staten Island:0
# ['Staten Island', 'Travis', 40.58631375103281, -74.19073717538116]
# ( 212 / 306 ) Japanese Restaurants in New Dorp, Staten Island:0
# ['Staten Island', 'New Dorp', 40.57257231820632, -74.1164794360638]
# ( 213 / 306 ) Japanese Restaurants in Oakwood, Staten Island:0
# ['Staten Island', 'Oakwood', 40.5584622432888, -74.12156593771896]
# ( 214 / 306 ) Japanese Restaurants in Great Kills, Staten Island:1
# ['Staten Island', 'Great Kills', 40.549480228713605, -74.14932381490992]
# ( 215 / 306 ) Japanese Restaurants in Eltingville, Staten Island:0
# ['Staten Island', 'Eltingville', 40.542230747450745, -74.1643308041936]
# ( 216 / 306 ) Japanese Restaurants in Annadale, Staten Island:0
# ['Staten Island', 'Annadale', 40.53811417474507, -74.17854866165878]
# ( 217 / 306 ) Japanese Restaurants in Woodrow, Staten Island:0
# ['Staten Island', 'Woodrow', 40.541967622888755, -74.20524582480326]
# ( 218 / 306 ) Japanese Restaurants in Tottenville, Staten Island:0
# ['Staten Island', 'Tottenville', 40.50533376115642, -74.24656934235283]
# ( 219 / 306 ) Japanese Restaurants in Tompkinsville, Staten Island:0
# ['Staten Island', 'Tompkinsville', 40.637316067110326, -74.08055351790115]
# ( 220 / 306 ) Japanese Restaurants in Silver Lake, Staten Island:0
# ['Staten Island', 'Silver Lake', 40.61919310792676, -74.09629029235458]
# ( 221 / 306 ) Japanese Restaurants in Sunnyside, Staten Island:0
# ['Staten Island', 'Sunnyside', 40.61276015756489, -74.0971255217853]
# ( 222 / 306 ) Japanese Restaurants in Ditmas Park, Brooklyn:0
# ['Brooklyn', 'Ditmas Park', 40.643675183340974, -73.96101312466779]
# ( 223 / 306 ) Japanese Restaurants in Wingate, Brooklyn:0
# ['Brooklyn', 'Wingate', 40.66094656188111, -73.93718680559314]
# ( 224 / 306 ) Japanese Restaurants in Rugby, Brooklyn:0
# ['Brooklyn', 'Rugby', 40.655572313280764, -73.92688212616955]
# ( 225 / 306 ) Japanese Restaurants in Park Hill, Staten Island:0
# ['Staten Island', 'Park Hill', 40.60919044434558, -74.08015734936296]
# ( 226 / 306 ) Japanese Restaurants in Westerleigh, Staten Island:0
# ['Staten Island', 'Westerleigh', 40.62109047275409, -74.13304143951704]
# ( 227 / 306 ) Japanese Restaurants in Graniteville, Staten Island:0
# ['Staten Island', 'Graniteville', 40.620171512231884, -74.15315246387762]
# ( 228 / 306 ) Japanese Restaurants in Arlington, Staten Island:0
# ['Staten Island', 'Arlington', 40.63532509911492, -74.16510420241124]
# ( 229 / 306 ) Japanese Restaurants in Arrochar, Staten Island:0
# ['Staten Island', 'Arrochar', 40.596312571276734, -74.06712363225574]
# ( 230 / 306 ) Japanese Restaurants in Grasmere, Staten Island:1
# ['Staten Island', 'Grasmere', 40.59826835959991, -74.0766743627905]
# ( 231 / 306 ) Japanese Restaurants in Old Town, Staten Island:0
# ['Staten Island', 'Old Town', 40.59632891379513, -74.08751118005578]
# ( 232 / 306 ) Japanese Restaurants in Dongan Hills, Staten Island:0
# ['Staten Island', 'Dongan Hills', 40.588672948199275, -74.09639905312521]
# ( 233 / 306 ) Japanese Restaurants in Midland Beach, Staten Island:0
# ['Staten Island', 'Midland Beach', 40.57352690574283, -74.09348266303591]
# ( 234 / 306 ) Japanese Restaurants in Grant City, Staten Island:0
# ['Staten Island', 'Grant City', 40.57621558711788, -74.10585598545434]
# ( 235 / 306 ) Japanese Restaurants in New Dorp Beach, Staten Island:0
# ['Staten Island', 'New Dorp Beach', 40.56425549307335, -74.10432707469124]
# ( 236 / 306 ) Japanese Restaurants in Bay Terrace, Staten Island:0
# ['Staten Island', 'Bay Terrace', 40.55398800858462, -74.13916622175768]
# ( 237 / 306 ) Japanese Restaurants in Huguenot, Staten Island:0
# ['Staten Island', 'Huguenot', 40.531911920489605, -74.19174105747814]
# ( 238 / 306 ) Japanese Restaurants in Pleasant Plains, Staten Island:0
# ['Staten Island', 'Pleasant Plains', 40.524699376118136, -74.21983106616777]
# ( 239 / 306 ) Japanese Restaurants in Butler Manor, Staten Island:0
# ['Staten Island', 'Butler Manor', 40.50608165346305, -74.22950350260027]
# ( 240 / 306 ) Japanese Restaurants in Charleston, Staten Island:0
# ['Staten Island', 'Charleston', 40.53053148283314, -74.23215775896526]
# ( 241 / 306 ) Japanese Restaurants in Rossville, Staten Island:0
# ['Staten Island', 'Rossville', 40.54940400650072, -74.21572851113952]
# ( 242 / 306 ) Japanese Restaurants in Arden Heights, Staten Island:0
# ['Staten Island', 'Arden Heights', 40.54928582278321, -74.18588674583893]
# ( 243 / 306 ) Japanese Restaurants in Greenridge, Staten Island:0
# ['Staten Island', 'Greenridge', 40.555295236173194, -74.17079414786092]
# ( 244 / 306 ) Japanese Restaurants in Heartland Village, Staten Island:0
# ['Staten Island', 'Heartland Village', 40.58913894875281, -74.15902208156601]
# ( 245 / 306 ) Japanese Restaurants in Chelsea, Staten Island:0
# ['Staten Island', 'Chelsea', 40.59472602746295, -74.1895604551969]
# ( 246 / 306 ) Japanese Restaurants in Bloomfield, Staten Island:0
# ['Staten Island', 'Bloomfield', 40.60577868452358, -74.18725638381567]
# ( 247 / 306 ) Japanese Restaurants in Bulls Head, Staten Island:1
# ['Staten Island', 'Bulls Head', 40.6095918004203, -74.15940948657122]
# ( 248 / 306 ) Japanese Restaurants in Carnegie Hill, Manhattan:0
# ['Manhattan', 'Carnegie Hill', 40.7826825671257, -73.95325646837112]
# ( 249 / 306 ) Japanese Restaurants in Noho, Manhattan:1
# ['Manhattan', 'Noho', 40.72325901885768, -73.98843368023597]
# ( 250 / 306 ) Japanese Restaurants in Civic Center, Manhattan:0
# ['Manhattan', 'Civic Center', 40.71522892046282, -74.00541529873355]
# ( 251 / 306 ) Japanese Restaurants in Midtown South, Manhattan:4
# ['Manhattan', 'Midtown South', 40.7485096643122, -73.98871313285247]
# ( 252 / 306 ) Japanese Restaurants in Richmond Town, Staten Island:0
# ['Staten Island', 'Richmond Town', 40.56960594275505, -74.1340572986257]
# ( 253 / 306 ) Japanese Restaurants in Shore Acres, Staten Island:0
# ['Staten Island', 'Shore Acres', 40.60971934079284, -74.06667766061771]
# ( 254 / 306 ) Japanese Restaurants in Clifton, Staten Island:0
# ['Staten Island', 'Clifton', 40.61917845202843, -74.072642445484]
# ( 255 / 306 ) Japanese Restaurants in Concord, Staten Island:0
# ['Staten Island', 'Concord', 40.6044731896879, -74.08402364740358]
# ( 256 / 306 ) Japanese Restaurants in Emerson Hill, Staten Island:0
# ['Staten Island', 'Emerson Hill', 40.606794394801, -74.09776206972522]
# ( 257 / 306 ) Japanese Restaurants in Randall Manor, Staten Island:0
# ['Staten Island', 'Randall Manor', 40.63563000681151, -74.09805062373887]
# ( 258 / 306 ) Japanese Restaurants in Howland Hook, Staten Island:0
# ['Staten Island', 'Howland Hook', 40.63843283794795, -74.18622331749823]
# ( 259 / 306 ) Japanese Restaurants in Elm Park, Staten Island:0
# ['Staten Island', 'Elm Park', 40.630146741193826, -74.1418167896889]
# ( 260 / 306 ) Japanese Restaurants in Remsen Village, Brooklyn:0
# ['Brooklyn', 'Remsen Village', 40.652117451793494, -73.91665331978048]
# ( 261 / 306 ) Japanese Restaurants in New Lots, Brooklyn:0
# ['Brooklyn', 'New Lots', 40.6627442796966, -73.88511776379292]
# ( 262 / 306 ) Japanese Restaurants in Paerdegat Basin, Brooklyn:0
# ['Brooklyn', 'Paerdegat Basin', 40.63131755039667, -73.90233474295836]
# ( 263 / 306 ) Japanese Restaurants in Mill Basin, Brooklyn:2
# ['Brooklyn', 'Mill Basin', 40.61597423962336, -73.91515391550404]
# ( 264 / 306 ) Japanese Restaurants in Jamaica Hills, Queens:0
# ['Queens', 'Jamaica Hills', 40.71145964370482, -73.79646462081593]
# ( 265 / 306 ) Japanese Restaurants in Utopia, Queens:0
# ['Queens', 'Utopia', 40.73350025429757, -73.79671678028349]
# ( 266 / 306 ) Japanese Restaurants in Pomonok, Queens:1
# ['Queens', 'Pomonok', 40.73493618075478, -73.80486120040537]
# ( 267 / 306 ) Japanese Restaurants in Astoria Heights, Queens:0
# ['Queens', 'Astoria Heights', 40.7703173929982, -73.89467996270574]
# ( 268 / 306 ) Japanese Restaurants in Claremont Village, Bronx:0
# ['Bronx', 'Claremont Village', 40.83142834161548, -73.90119903387667]
# ( 269 / 306 ) Japanese Restaurants in Concourse Village, Bronx:1
# ['Bronx', 'Concourse Village', 40.824780490842905, -73.91584652759009]
# ( 270 / 306 ) Japanese Restaurants in Mount Eden, Bronx:0
# ['Bronx', 'Mount Eden', 40.84382617671654, -73.91655551964419]
# ( 271 / 306 ) Japanese Restaurants in Mount Hope, Bronx:0
# ['Bronx', 'Mount Hope', 40.84884160724665, -73.90829930881988]
# ( 272 / 306 ) Japanese Restaurants in Sutton Place, Manhattan:0
# ['Manhattan', 'Sutton Place', 40.76028033131374, -73.96355614094303]
# ( 273 / 306 ) Japanese Restaurants in Hunters Point, Queens:3
# ['Queens', 'Hunters Point', 40.743414090073536, -73.95386782130745]
# ( 274 / 306 ) Japanese Restaurants in Turtle Bay, Manhattan:0
# ['Manhattan', 'Turtle Bay', 40.75204236950722, -73.96770824581834]
# ( 275 / 306 ) Japanese Restaurants in Tudor City, Manhattan:1
# ['Manhattan', 'Tudor City', 40.746917410740195, -73.97121928722265]
# ( 276 / 306 ) Japanese Restaurants in Stuyvesant Town, Manhattan:0
# ['Manhattan', 'Stuyvesant Town', 40.73099955477061, -73.97405170469203]
# ( 277 / 306 ) Japanese Restaurants in Flatiron, Manhattan:4
# ['Manhattan', 'Flatiron', 40.739673047638426, -73.9909471052826]
# ( 278 / 306 ) Japanese Restaurants in Sunnyside Gardens, Queens:1
# ['Queens', 'Sunnyside Gardens', 40.74565180608076, -73.91819286431682]
# ( 279 / 306 ) Japanese Restaurants in Blissville, Queens:0
# ['Queens', 'Blissville', 40.73725071694497, -73.93244235260178]
# ( 280 / 306 ) Japanese Restaurants in Fulton Ferry, Brooklyn:1
# ['Brooklyn', 'Fulton Ferry', 40.70328109093014, -73.99550751888415]
# ( 281 / 306 ) Japanese Restaurants in Vinegar Hill, Brooklyn:0
# ['Brooklyn', 'Vinegar Hill', 40.70332149882874, -73.98111603592393]
# ( 282 / 306 ) Japanese Restaurants in Weeksville, Brooklyn:0
# ['Brooklyn', 'Weeksville', 40.67503986503237, -73.93053108817338]
# ( 283 / 306 ) Japanese Restaurants in Broadway Junction, Brooklyn:0
# ['Brooklyn', 'Broadway Junction', 40.67786104769531, -73.90331684852599]
# ( 284 / 306 ) Japanese Restaurants in Dumbo, Brooklyn:0
# ['Brooklyn', 'Dumbo', 40.70317632822692, -73.9887528074504]
# ( 285 / 306 ) Japanese Restaurants in Manor Heights, Staten Island:0
# ['Staten Island', 'Manor Heights', 40.60180957631444, -74.12059399718001]
# ( 286 / 306 ) Japanese Restaurants in Willowbrook, Staten Island:0
# ['Staten Island', 'Willowbrook', 40.60370692627371, -74.13208447484298]
# ( 287 / 306 ) Japanese Restaurants in Sandy Ground, Staten Island:0
# ['Staten Island', 'Sandy Ground', 40.541139922091766, -74.21776636068567]
# ( 288 / 306 ) Japanese Restaurants in Egbertville, Staten Island:0
# ['Staten Island', 'Egbertville', 40.579118742961214, -74.12727240604946]
# ( 289 / 306 ) Japanese Restaurants in Roxbury, Queens:0
# ['Queens', 'Roxbury', 40.56737588957032, -73.89213760232822]
# ( 290 / 306 ) Japanese Restaurants in Homecrest, Brooklyn:0
# ['Brooklyn', 'Homecrest', 40.598525095137255, -73.95918459428702]
# ( 291 / 306 ) Japanese Restaurants in Middle Village, Queens:0
# ['Queens', 'Middle Village', 40.716414511158185, -73.88114319200604]
# ( 292 / 306 ) Japanese Restaurants in Prince's Bay, Staten Island:0
# ['Staten Island', "Prince's Bay", 40.52626406734812, -74.20152556457658]
# ( 293 / 306 ) Japanese Restaurants in Lighthouse Hill, Staten Island:0
# ['Staten Island', 'Lighthouse Hill', 40.57650629379489, -74.13792663771568]
# ( 294 / 306 ) Japanese Restaurants in Richmond Valley, Staten Island:0
# ['Staten Island', 'Richmond Valley', 40.51954145748909, -74.22957080626941]
# ( 295 / 306 ) Japanese Restaurants in Malba, Queens:0
# ['Queens', 'Malba', 40.79060155670148, -73.82667757138641]
# ( 296 / 306 ) Japanese Restaurants in Highland Park, Brooklyn:0
# ['Brooklyn', 'Highland Park', 40.6819989345173, -73.890345709872]
# ( 297 / 306 ) Japanese Restaurants in Madison, Brooklyn:0
# ['Brooklyn', 'Madison', 40.60937770113766, -73.94841515328893]
# ( 298 / 306 ) Japanese Restaurants in Bronxdale, Bronx:0
# ['Bronx', 'Bronxdale', 40.85272297633017, -73.86172577555115]
# ( 299 / 306 ) Japanese Restaurants in Allerton, Bronx:0
# ['Bronx', 'Allerton', 40.86578787802982, -73.85931863221647]
# ( 300 / 306 ) Japanese Restaurants in Kingsbridge Heights, Bronx:0
# ['Bronx', 'Kingsbridge Heights', 40.8703923914147, -73.90152264513144]
# ( 301 / 306 ) Japanese Restaurants in Erasmus, Brooklyn:0
# ['Brooklyn', 'Erasmus', 40.64692606658579, -73.94817709920184]
# ( 302 / 306 ) Japanese Restaurants in Hudson Yards, Manhattan:0
# ['Manhattan', 'Hudson Yards', 40.75665808227519, -74.00011136202637]
# ( 303 / 306 ) Japanese Restaurants in Hammels, Queens:0
# ['Queens', 'Hammels', 40.58733774018741, -73.80553002968718]
# ( 304 / 306 ) Japanese Restaurants in Bayswater, Queens:0
# ['Queens', 'Bayswater', 40.611321691283834, -73.76596781445627]
# ( 305 / 306 ) Japanese Restaurants in Queensbridge, Queens:0
# ['Queens', 'Queensbridge', 40.756091297094706, -73.94563070334091]
# ( 306 / 306 ) Japanese Restaurants in Fox Hills, Staten Island:0
# ['Staten Island', 'Fox Hills', 40.61731079252983, -74.08173992211962]

# %%
#japanese_rest_ny.to_csv('japanese_rest_ny_tocsv1.csv') # Save the information so far to a .csv file due to limited calls on FourSquare
japanese_rest_ny.to_csv('japanese_rest_ny_tocsv1.csv')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-8d65cc4f3efe> in <module>
#       1 #japanese_rest_ny.to_csv('japanese_rest_ny_tocsv1.csv') # Save the information so far to a .csv file due to limited calls on FourSquare
# ----> 2 japanese_rest_ny.to_csv('japanese_rest_ny_tocsv1.csv')
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3178             Make the row labels bold in the output.
#    3179         column_format : str, optional
# -> 3180             The columns format as specified in `LaTeX table format
#    3181             <https://en.wikibooks.org/wiki/LaTeX/Tables>`__ e.g. 'rcl' for 3
#    3182             columns. By default, 'l' will be used for all columns except
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/formats/csvs.py in <module>
#      19
#      20 from pandas._libs import writers as libwriters
# ---> 21 from pandas._typing import (
#      22     CompressionOptions,
#      23     FilePathOrBuffer,
#
# ImportError: cannot import name 'CompressionOptions' from 'pandas._typing' (/opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/_typing.py)

# %%
japanese_ny = pd.read_csv('japanese_rest_ny_tocsv1.csv')
japanese_rest_ny.tail()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-c0e7813a8c75> in <module>
# ----> 1 japanese_ny = pd.read_csv('japanese_rest_ny_tocsv1.csv')
#       2 japanese_rest_ny.tail()
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File japanese_rest_ny_tocsv1.csv does not exist: 'japanese_rest_ny_tocsv1.csv'

# %%
japanese_rest_ny.shape
# Out:
# (65, 4)

# %%
japanese_rest_ny.groupby('Borough')['ID'].count().plot.bar(figsize=(10,5), color=clr)
plt.title('Japanese Restaurants per Borough: NYC', fontsize = 20)
plt.xlabel('Borough', fontsize = 15)
plt.ylabel('No. of Japanese Restaurants', fontsize=15)
plt.xticks(rotation = 'horizontal')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-a0a0a74bf4fe> in <module>
# ----> 1 japanese_rest_ny.groupby('Borough')['ID'].count().plot.bar(figsize=(10,5), color=clr)
#       2 plt.title('Japanese Restaurants per Borough: NYC', fontsize = 20)
#       3 plt.xlabel('Borough', fontsize = 15)
#       4 plt.ylabel('No. of Japanese Restaurants', fontsize=15)
#       5 plt.xticks(rotation = 'horizontal')
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/plotting/_core.py in bar(self, x, y, **kwargs)
#    1001             >>> lines = df.plot.line()
#    1002
# -> 1003         .. plot::
#    1004            :context: close-figs
#    1005
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     765     Returns
#     766     -------
# --> 767     :class:`matplotlib.axes.Axes` or numpy.ndarray of them
#     768         If the backend is not the default matplotlib one, the return value
#     769         will be the object returned by the backend.
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1667             chosen in a way that the hexagons are approximately regular.
#    1668             Alternatively, gridsize can be a tuple with two elements
# -> 1669             specifying the number of hexagons in the x-direction and the
#    1670             y-direction.
#    1671         **kwargs
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.

# %%
NOofNeigh = 6 # top number for graphing all the same past 6
japanese_rest_ny.groupby('Neighborhood')['ID'].count().nlargest(NOofNeigh).plot.bar(figsize=(10,5), color=clr)
plt.title('Japanese Restaurants per Neighborhood: NYC', fontsize = 20)
plt.xlabel('Neighborhood', fontsize = 15)
plt.ylabel('No. of Japanese Restaurants', fontsize=15)
plt.xticks(rotation = 'horizontal')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-6d9e3387c3ff> in <module>
#       1 NOofNeigh = 6 # top number for graphing all the same past 6
# ----> 2 japanese_rest_ny.groupby('Neighborhood')['ID'].count().nlargest(NOofNeigh).plot.bar(figsize=(10,5), color=clr)
#       3 plt.title('Japanese Restaurants per Neighborhood: NYC', fontsize = 20)
#       4 plt.xlabel('Neighborhood', fontsize = 15)
#       5 plt.ylabel('No. of Japanese Restaurants', fontsize=15)
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/plotting/_core.py in bar(self, x, y, **kwargs)
#    1001             >>> lines = df.plot.line()
#    1002
# -> 1003         .. plot::
#    1004            :context: close-figs
#    1005
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     765     Returns
#     766     -------
# --> 767     :class:`matplotlib.axes.Axes` or numpy.ndarray of them
#     768         If the backend is not the default matplotlib one, the return value
#     769         will be the object returned by the backend.
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1667             chosen in a way that the hexagons are approximately regular.
#    1668             Alternatively, gridsize can be a tuple with two elements
# -> 1669             specifying the number of hexagons in the x-direction and the
#    1670             y-direction.
#    1671         **kwargs
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.

# %%
japanese_rest_ny[japanese_rest_ny['Neighborhood']=='Murray Hill']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/frame.py in _repr_html_(self)
#     732             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#     733             # expected "Union[Union[Union[ExtensionArray, ndarray],
# --> 734             # Index, Series], Sequence[Any]]"
#     735             index = ensure_index(index)  # type: ignore[arg-type]
#     736             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/formats/format.py in to_html(self, buf, encoding, classes, notebook, border)
#     980         string = latex_formatter.to_string()
#     981         return save_to_buffer(string, buf=buf, encoding=encoding)
# --> 982
#     983     def to_html(
#     984         self,
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/formats/html.py in __init__(self, formatter, classes, border, table_id, render_links)
#      66         self.col_space = {
#      67             column: f"{value}px" if isinstance(value, int) else value
# ---> 68             for column, value in self.fmt.col_space.items()
#      69         }
#      70
#
# AttributeError: 'NoneType' object has no attribute 'items'
#       Borough Neighborhood                        ID            Name
# 21  Manhattan  Murray Hill  4a99b4f4f964a520f62f20e3         Kajitsu
# 22  Manhattan  Murray Hill  559cbaa6498eaa4e8d884811  Tempura Matsui
# 23  Manhattan  Murray Hill  591caee89deb7d0f69be77a2  Omusubi Gonbei
# 24  Manhattan  Murray Hill  540dc46d498e86f0e5059dd2   Zuma New York
# 38     Queens  Murray Hill  4bc8eee83740b713fcbe5d65  Northern Sushi

# %%
column_names=['Borough', 'Neighborhood', 'ID','Name','Likes','Rating','Tips']
japanese_rest_stats_ny=pd.DataFrame(columns=column_names)
count=1
for row in japanese_rest_ny.values.tolist():
    Borough,Neighborhood,ID,Name=row
    try:
        venue_details=get_venue_details(ID)
        print(venue_details)
        id,name,likes,rating,tips=venue_details.values.tolist()[0]
    except IndexError:
        print('No data available for id=',ID)
        # we will assign 0 value for these resturants as they may have been 
        #recently opened or details does not exist in FourSquare Database
        id,name,likes,rating,tips=[0]*5
    print('(',count,'/',len(japanese_rest_ny),')','processed')
    japanese_rest_stats_ny = japanese_rest_stats_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name,
                                                'Likes' : likes,
                                                'Rating' : rating,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1
japanese_rest_stats_ny.tail()
# Out:
# {'meta': {'code': 200, 'requestId': '60e40ee8911351717e777649'}, 'response': {'venue': {'id': '4d5c12a01e43236a87eb1583', 'name': 'Sake Sushi', 'contact': {'phone': '7188515299', 'formattedPhone': '(718) 851-5299'}, 'location': {'address': '328 Church Ave', 'crossStreet': 'East 4th Street', 'lat': 40.644138, 'lng': -73.976439, 'labeledLatLngs': [{'label': 'display', 'lat': 40.644138, 'lng': -73.976439}], 'postalCode': '11218', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['328 Church Ave (East 4th Street)', 'Brooklyn, NY 11218', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/sake-sushi/4d5c12a01e43236a87eb1583', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 49}, 'url': 'http://sakesushiny.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 31, 'groups': [{'type': 'others', 'count': 31, 'items': []}], 'summary': '31 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.1, 'ratingColor': '73CF42', 'ratingSignals': 36, 'delivery': {'id': '2732346', 'url': 'https://www.seamless.com/menu/sake-japanese-cuisine-328-church-ave-brooklyn/2732346?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2732346', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/sake-sushi/4d5c12a01e43236a87eb1583/menu', 'mobileUrl': 'https://foursquare.com/v/4d5c12a01e43236a87eb1583/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 82, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 82, 'items': [{'id': '4f6d0988e4b0a4e20f3f77b8', 'createdAt': 1332545928, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/Xo5PAEK9J2eNbn7Lb8-l8F8W-T1bGbPHxairx1W4OH4.jpg', 'width': 540, 'height': 540, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1297879712, 'tips': {'count': 49, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 49, 'items': [{'id': '509967b9e4b0c4f0ff00146d', 'createdAt': 1352230841, 'text': 'Great service and always fresh !', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/509967b9e4b0c4f0ff00146d', 'lang': 'en', 'likes': {'count': 13, 'groups': [{'type': 'others', 'count': 13, 'items': []}], 'summary': '13 likes'}, 'logView': True, 'agreeCount': 13, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Malibu', 'lastName': 'D', 'countryCode': 'US'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/gawW1x', 'timeZone': 'America/New_York', 'listed': {'count': 13, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 13, 'items': [{'id': '5d5971650b8bda0006807730', 'name': 'Awesome Kensington Brooklyn Places', 'description': 'All the best spots to go when you’re in Kensington Brooklyn', 'type': 'others', 'user': {'firstName': 'Shawn', 'lastName': 'C', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/shacheng/list/awesome-kensington-brooklyn-places', 'canonicalUrl': 'https://foursquare.com/shacheng/list/awesome-kensington-brooklyn-places', 'createdAt': 1566142821, 'updatedAt': 1 ...
#                          ID        Name  Likes  Rating  Tips
# 0  4d5c12a01e43236a87eb1583  Sake Sushi     31     8.1    49
# ( 1 / 65 ) processed
# {'meta': {'code': 200, 'requestId': '60e40ee8cb459146f31a4364'}, 'response': {'venue': {'id': '5cb5e5f9a35f4600255406c6', 'name': 'Maison Yaki', 'contact': {'phone': '7185522609', 'formattedPhone': '(718) 552-2609', 'twitter': 'maisonyaki', 'instagram': 'maisonyaki', 'facebook': '272996516936741', 'facebookUsername': 'maisonyaki', 'facebookName': 'Maison Yaki'}, 'location': {'address': '626 Vanderbilt Ave', 'crossStreet': 'Prospect Place', 'lat': 40.67747521328162, 'lng': -73.96908078141962, 'labeledLatLngs': [{'label': 'display', 'lat': 40.67747521328162, 'lng': -73.96908078141962}], 'postalCode': '11238', 'cc': 'US', 'neighborhood': 'Prospect Heights', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['626 Vanderbilt Ave (Prospect Place)', 'Brooklyn, NY 11238', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/maison-yaki/5cb5e5f9a35f4600255406c6', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 23}, 'url': 'http://www.maisonyaki.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 89, 'groups': [{'type': 'others', 'count': 89, 'items': []}], 'summary': '89 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.3, 'ratingColor': 'C5DE35', 'ratingSignals': 76, 'delivery': {'id': '2569903', 'url': 'https://www.seamless.com/menu/maison-yaki-626-vanderbilt-ave-brooklyn/2569903?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2569903', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 109, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 109, 'items': [{'id': '60e1ef97e02e4478aaed6876', 'createdAt': 1625419671, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/33533994_274zsrIAYpq_8_WVH03b4H3oNrWDhC8F4Y6I40vQQLk.jpg', 'width': 1920, 'height': 1440, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1555424761, 'tips': {'count': 23, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 23, 'items': [{'id': '5d8d7f10f6e11100076fe3b8', 'createdAt': 1569554192, 'text': 'The crispy potatoes and cauliflower cake were my favorite. Good cocktails too and great service. The skewers were fine but a bit overpriced.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5d8d7f10f6e11100076fe3b8', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Milagros', 'lastName': 'R', 'countryCode': 'US'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'https://4sq.com/2DgX3FQ', 'timeZone': 'America/New_York', 'listed': {'count': 276, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 276, 'items': [{'id': '51d1aca6498e703ff46f55d4', 'name': 'Dinnertime seduction in NYC', 'description': 'You like to eat, I like to eat. Lets date.', 'type': 'others', 'user': {'firstName': 'Kim', 'lastName': 'P', 'countryCode': 'US'}, 'editable': False, 'public': True, 'c ...
#                          ID         Name  Likes  Rating  Tips
# 0  5cb5e5f9a35f4600255406c6  Maison Yaki     89     7.3    23
# ( 2 / 65 ) processed
# {'meta': {'code': 200, 'requestId': '60e40ee9a770ad0018d328b9'}, 'response': {'venue': {'id': '51f9b7b3498eefe896caeb23', 'name': 'Shalom Japan', 'contact': {'phone': '7183884012', 'formattedPhone': '(718) 388-4012', 'twitter': 'shalomjapan'}, 'location': {'address': '310 S 4th St', 'crossStreet': 'at Rodney St', 'lat': 40.709219, 'lng': -73.955839, 'labeledLatLngs': [{'label': 'display', 'lat': 40.709219, 'lng': -73.955839}], 'postalCode': '11211', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['310 S 4th St (at Rodney St)', 'Brooklyn, NY 11211', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/shalom-japan/51f9b7b3498eefe896caeb23', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}, {'id': '52e81612bcbc57f1066b79fd', 'name': 'Jewish Restaurant', 'pluralName': 'Jewish Restaurants', 'shortName': 'Jewish', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}}], 'verified': True, 'stats': {'tipCount': 99}, 'url': 'http://shalomjapannyc.com', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 304, 'groups': [{'type': 'others', 'count': 304, 'items': []}], 'summary': '304 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.5, 'ratingColor': 'C5DE35', 'ratingSignals': 259, 'delivery': {'id': '1340897', 'url': 'https://www.seamless.com/menu/shalom-japan-310-s-4th-st-brooklyn/1340897?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1340897', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/shalom-japan/51f9b7b3498eefe896caeb23/menu', 'mobileUrl': 'https://foursquare.com/v/51f9b7b3498eefe896caeb23/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 224, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 224, 'items': [{'id': '520aa9838bbdd820570695a1', 'createdAt': 1376430467, 'source': {'name': 'Foursquare Web', 'url': 'https://foursquare.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/63677960_GvLNFbFRCDA2NkAq6AdScrTxXgPJZOfI6I3d0DT0Pg8.jpg', 'width': 555, 'height': 370, 'visibility': 'public'}]}]}, 'venuePage': {'id': '63677960'}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'The menu is a \x03playful and seasonal approach to New American cuisine, highlighting the chefs’ connections to their respective Jewish and Japanese roots.', 'storeId': '', 'page': {'user': {'firstName': 'Shalom Japan', 'countryCode': 'US', 'type': 'venuePage', 'venue': {'id': '51f9b7b3498eefe896caeb23'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1375319987, 'tips': {'count': 99, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 99, 'items': [{'id': '525c622d498e773643744445', 'createdAt': 1381786157, 'text': '“Shalom Japan...sounds almost like the punch line to a joke—but the married couple Aaron Israel and Sawako Okochi…are far from kidding around. At its best, their food is fusion in the truest sense.”', 'type': 'user', 'url': 'http://www.newyorker.com/arts/reviews/tables/2013/10/21/131021gota_GOAT_tables_goldfield', 'canonicalUrl': 'https://foursquare.com/item/525c622d498e773643744445', 'photo': {'id': '525c622d11d2e9a0 ...
#                          ID          Name  Likes  Rating  Tips
# 0  51f9b7b3498eefe896caeb23  Shalom Japan    304     7.5    99
# ( 3 / 65 ) processed
# {'meta': {'code': 200, 'requestId': '60e40ee9d9341337b6e1f494'}, 'response': {'venue': {'id': '5b3bcb69bfc6d0002ca9bf17', 'name': 'Warude', 'contact': {}, 'location': {'address': '387 Tompkins', 'lat': 40.684409678801586, 'lng': -73.94411847251774, 'labeledLatLngs': [{'label': 'display', 'lat': 40.684409678801586, 'lng': -73.94411847251774}], 'postalCode': '11216', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['387 Tompkins', 'New York, NY 11216', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/warude/5b3bcb69bfc6d0002ca9bf17', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 6}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 32, 'groups': [{'type': 'others', 'count': 32, 'items': []}], 'summary': '32 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.6, 'ratingColor': 'C5DE35', 'ratingSignals': 21, 'delivery': {'id': '1049175', 'url': 'https://www.seamless.com/menu/warude-japanese-bowl-385-tompkins-ave-brooklyn/1049175?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1049175', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 25, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 25, 'items': [{'id': '60d15b017b3c2b5b9236346b', 'createdAt': 1624333057, 'source': {'name': 'Swarm for Android', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/136903278_zR9MsJM5XfmBHiFiJb4BkGYi0ELFbofYb-VcYE6txHg.jpg', 'width': 1080, 'height': 607, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1530645353, 'tips': {'count': 6, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 6, 'items': [{'id': '5c7ae86fde3bbf002c3471b6', 'createdAt': 1551558767, 'text': 'Best... wings... ever...', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5c7ae86fde3bbf002c3471b6', 'photo': {'id': '5c7ae2766e4650002cfc5ada', 'createdAt': 1551557238, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/4675337_J2UdPMHHr760vLovAAI1u8HZcOP3Seweh6jlRgbsRwA.jpg', 'width': 1440, 'height': 1920, 'visibility': 'public'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/4675337_J2UdPMHHr760vLovAAI1u8HZcOP3Seweh6jlRgbsRwA.jpg', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Andreas', 'lastName': 'W', 'countryCode': 'US'}}]}]}, 'shortUrl': 'https://4sq.com/2lTIGye', 'timeZone': 'America/New_York', 'listed': {'count': 28, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 28, 'items': [{'id': '5c028cd6fc9e94002c0312dd', 'name': 'Brooklyn Food & Drink', 'description': '', 'type': 'others', 'user': {'firstName': 'Eva', 'lastName': 'G', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/142243619/list/brooklyn-food--drink', 'canonicalUrl': 'https://foursquare.co ...
#                          ID    Name  Likes  Rating  Tips
# 0  5b3bcb69bfc6d0002ca9bf17  Warude     32     7.6     6
# ( 4 / 65 ) processed
# {'meta': {'code': 200, 'requestId': '60e40ee98492d94983536f44'}, 'response': {'venue': {'id': '479ccb47f964a5206b4d1fe3', 'name': 'Iron Chef House', 'contact': {'phone': '7188588517', 'formattedPhone': '(718) 858-8517', 'facebook': '115805155108798', 'facebookUsername': 'IronChefHouse', 'facebookName': 'Iron Chef House'}, 'location': {'address': '92 Clark St', 'crossStreet': 'Henry St', 'lat': 40.697405738767394, 'lng': -73.99256031665585, 'labeledLatLngs': [{'label': 'display', 'lat': 40.697405738767394, 'lng': -73.99256031665585}, {'label': 'entrance', 'lat': 40.69726, 'lng': -73.992604}], 'postalCode': '11201', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['92 Clark St (Henry St)', 'Brooklyn, NY 11201', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/iron-chef-house/479ccb47f964a5206b4d1fe3', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1d2941735', 'name': 'Sushi Restaurant', 'pluralName': 'Sushi Restaurants', 'shortName': 'Sushi', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 66}, 'url': 'http://www.ironchefbrooklyn.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'dislike': False, 'ok': False, 'rating': 7.5, 'ratingColor': 'C5DE35', 'ratingSignals': 137, 'delivery': {'id': '332269', 'url': 'https://www.seamless.com/menu/iron-chef-house-92-clark-st-brooklyn/332269?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=332269', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/iron-chef-house/479ccb47f964a5206b4d1fe3/menu', 'mobileUrl': 'https://foursquare.com/v/479ccb47f964a5206b4d1fe3/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 84, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 84, 'items': [{'id': '5106d163e4b081fc54fc44a0', 'createdAt': 1359401315, 'source': {'name': 'Instagram', 'url': 'http://instagram.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/3460182_o2s3fX0vE5qA7nw_-GqXT3kYFGmIpFVoOZGfj-FjfdM.jpg', 'width': 612, 'height': 612, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'We offer an experience at our Japanese Restaurant and everyone is raving about it! At the Iron Chef House our Japanese cuisine is top quality by highly experienced chefs! We have the best Sushi and Sashimi around, and great reviews from our guests as well...', 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1201457991, 'tips': {'count': 66, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 66, 'items': [{'id': '4f078b7fe4b0ad9c244e109c', 'createdAt': 1325894527, 'text': 'Best sushi in Brooklyn.. Monkey roll is amazing. An the NaMe tuna appetizer', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4f078b7fe4b0ad9c244e109c', 'lang': 'en', 'likes': {'count': 4, 'groups': [], 'summary': '4 likes'}, 'logView': True, 'agreeCount': 3, 'disagreeCount': 0, 'todo': {'count': 1}, 'user': {'firstName': 'Sonny', 'lastName': 'V', 'countryCode': 'US'}}]}]}, 'shortUrl': 'http://4sq.com/7ckhHC', 'timeZone': 'America/New_York', 'listed': {'count': 150, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'cou ...
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 479ccb47f964a5206b4d1fe3
# ( 5 / 65 ) processed
# {'meta': {'code': 200, 'requestId': '60e40eeb02a2b17c5a49ab1c'}, 'response': {'venue': {'id': '48a41073f964a52091511fe3', 'name': 'Hibino', 'contact': {'phone': '7182608052', 'formattedPhone': '(718) 260-8052', 'twitter': 'hibino_brooklyn', 'facebook': '301149720034179', 'facebookUsername': 'hibinobklyn', 'facebookName': 'Hibino Brooklyn'}, 'location': {'address': '333 Henry St', 'crossStreet': 'at Pacific St', 'lat': 40.69007601730789, 'lng': -73.99649744997076, 'labeledLatLngs': [{'label': 'display', 'lat': 40.69007601730789, 'lng': -73.99649744997076}, {'label': 'entrance', 'lat': 40.690164, 'lng': -73.996383}], 'postalCode': '11201', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['333 Henry St (at Pacific St)', 'Brooklyn, NY 11201', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/hibino/48a41073f964a52091511fe3', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1d2941735', 'name': 'Sushi Restaurant', 'pluralName': 'Sushi Restaurants', 'shortName': 'Sushi', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 157}, 'url': 'http://hibino-brooklyn.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 489, 'groups': [{'type': 'others', 'count': 489, 'items': []}], 'summary': '489 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.8, 'ratingColor': '73CF42', 'ratingSignals': 340, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'http://hibino-brooklyn.com/menu.html', 'mobileUrl': 'http://hibino-brooklyn.com/menu.html', 'externalUrl': 'http://hibino-brooklyn.com/menu.html'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 220, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 220, 'items': [{'id': '50f1ec3ce4b00d7fed23fde4', 'createdAt': 1358031932, 'source': {'name': 'Instagram', 'url': 'http://instagram.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/144127_Ps5Rw0LCemxnY2YKe6jjls4_zWJ3QJvnuEKBBWc3cT8.jpg', 'width': 612, 'height': 612, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1218711667, 'tips': {'count': 157, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 157, 'items': [{'id': '4bc3d09d70c603bb87a897b4', 'createdAt': 1271124125, 'text': 'Get the beef kakuni. The meat is very soft and quite delicious.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4bc3d09d70c603bb87a897b4', 'lang': 'en', 'likes': {'count': 7, 'groups': [{'type': 'others', 'count': 7, 'items': [{'firstName': 'Mashka', 'countryCode': 'RO'}, {'firstName': 'Ryan', 'lastName': 'K', 'countryCode': 'US'}, {'firstName': 'joan', 'lastName': 'l', 'countryCode': 'US'}]}], 'summary': '7 likes'}, 'logView': True, 'agreeCount': 3, 'disagreeCount': 0, 'todo': {'count': 2}, 'user': {'firstName': 'Allan', 'lastName': 'B', 'countryCode': 'US'}}]}]}, 'shortUrl': 'http://4sq.com/6d6cZm', 'timeZone': 'America/New_York', 'listed': {'count': 968, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 968, 'items': [{'id': '4de5360d922e6f938534d5b7', 'name': 'Must Eats in Cobble Hill / Carroll Gardens', 'description': 'some of my favorite spots to eat on smith, court and the surrounding area. feel free to build on this list with your own additions!', 'type': 'others', 'user': {'firstName': 'jake', 'lastName': 'f', 'countryCode': 'US'}, 'editable': False, 'pub ...
#                          ID    Name  Likes  Rating  Tips
# 0  48a41073f964a52091511fe3  Hibino    489     8.8   157
# ( 6 / 65 ) processed
# {'meta': {'code': 200, 'requestId': '60e40eeb911351717e777ce3'}, 'response': {'venue': {'id': '5e4f270b03b7910008721f2e', 'name': 'Karazishi Botan', 'contact': {'phone': '3477631155', 'formattedPhone': '(347) 763-1155', 'instagram': 'karazishi_botan', 'facebook': '110365083873021', 'facebookUsername': 'KarazishiBotanBKLYN', 'facebookName': 'Karazishi Botan'}, 'location': {'address': '255 Smith St', 'crossStreet': 'Degraw St', 'lat': 40.683154, 'lng': -73.992888, 'labeledLatLngs': [{'label': 'display', 'lat': 40.683154, 'lng': -73.992888}], 'postalCode': '11231', 'cc': 'US', 'neighborhood': 'Boerum Hill', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['255 Smith St (Degraw St)', 'Brooklyn, NY 11231', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/karazishi-botan/5e4f270b03b7910008721f2e', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}, {'id': '55a59bace4b013909087cb24', 'name': 'Ramen Restaurant', 'pluralName': 'Ramen Restaurants', 'shortName': 'Ramen', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 6}, 'url': 'https://www.karazishibotan.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 25, 'groups': [{'type': 'others', 'count': 25, 'items': []}], 'summary': '25 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.5, 'ratingColor': 'C5DE35', 'ratingSignals': 17, 'delivery': {'id': '2033720', 'url': 'https://www.seamless.com/menu/karazishi-botan-255-smith-st-brooklyn/2033720?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2033720', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 17, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 17, 'items': [{'id': '6071d8631524807b8c404ed1', 'createdAt': 1618073699, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/276818_arbMo-tRB8gYbqwNprG9OzUtYlH66INAoFkJhMOEiXo.jpg', 'width': 1440, 'height': 1920, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1582245643, 'tips': {'count': 6, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 6, 'items': [{'id': '6074e520ffb417177f204527', 'createdAt': 1618273568, 'text': 'Soft boiled egg perfect, the pork is not fatty at all, more lean white and kinda dryish.ramen and broth very good otherwise', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/6074e520ffb417177f204527', 'photo': {'id': '6074e520ffb417177f204526', 'createdAt': 1618273568, 'source': {'name': 'Swarm for Android', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/37016456_WVO2y7MkPQc_0cyYwgVGbTwZZ0azxG2uFS9iEv600WA.jpg', 'width': 1080, 'height': 1440, 'visibility': 'friends'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/37016456_WVO2y7MkPQc_0cyYwgVGbTwZZ0azxG2uFS9iEv600WA.jpg', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Christina', 'lastName': 'C', 'countryCode': 'US'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'https://4sq.com/39S3f4Q', 'timeZone': 'America/New_York', 'listed': {'count': 67, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 67, 'items': ...
#                          ID             Name  Likes  Rating  Tips
# 0  5e4f270b03b7910008721f2e  Karazishi Botan     25     7.5     6
# ( 7 / 65 ) processed
# {'meta': {'code': 200, 'requestId': '60e40eeccb459146f31a49a4'}, 'response': {'venue': {'id': '5276d39a498eb1a5d90096e4', 'name': 'Sushi Katsuei', 'contact': {'phone': '7187885338', 'formattedPhone': '(718) 788-5338', 'instagram': 'sushikatsuei', 'facebook': '566743240069984', 'facebookUsername': 'SushiKatsuei', 'facebookName': 'Sushi Katsuei'}, 'location': {'address': '210 7th Ave', 'crossStreet': 'at 3rd St', 'lat': 40.67061519402922, 'lng': -73.97850388946965, 'labeledLatLngs': [{'label': 'display', 'lat': 40.67061519402922, 'lng': -73.97850388946965}], 'postalCode': '11215', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['210 7th Ave (at 3rd St)', 'Brooklyn, NY 11215', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/sushi-katsuei/5276d39a498eb1a5d90096e4', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1d2941735', 'name': 'Sushi Restaurant', 'pluralName': 'Sushi Restaurants', 'shortName': 'Sushi', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 84}, 'url': 'https://www.sushikatsuei.com/parkslope-brooklyn-ny/', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'likes': {'count': 107, 'groups': [{'type': 'others', 'count': 107, 'items': []}], 'summary': '107 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.8, 'ratingColor': '73CF42', 'ratingSignals': 193, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://www.sushikatsuei.com/menu-brooklyn/', 'mobileUrl': 'https://www.sushikatsuei.com/menu-brooklyn/', 'externalUrl': 'https://www.sushikatsuei.com/menu-brooklyn/'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 298, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 298, 'items': [{'id': '52c1053611d2d969a9e980b3', 'createdAt': 1388381494, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/16897470_nYbcknsM46wp8r_fjL3tizv4hCRNK3GIpVdMXhT0ct0.jpg', 'width': 960, 'height': 656, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1383519130, 'tips': {'count': 84, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 84, 'items': [{'id': '54067184498e9ab6ba2295f4', 'createdAt': 1409708420, 'text': 'Best sushi ive had in all of Brooklyn. Get the sushi and sashimi omakase and some cold sake. This place literally made me feel like an idiot for eating at normal sushi restaurants. Come on payday.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/54067184498e9ab6ba2295f4', 'photo': {'id': '566afe4a498e06e272455f59', 'createdAt': 1449852490, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/4607987_FHNsOSWUpP3RIeWfCNp7ZTCjwLFqslsA1Ir5NBqSm7M.jpg', 'width': 1920, 'height': 1440, 'visibility': 'public'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/4607987_FHNsOSWUpP3RIeWfCNp7ZTCjwLFqslsA1Ir5NBqSm7M.jpg', 'lang': 'en', 'likes': {'count': 6, 'groups': [{'type': 'others', 'count': 6, 'items': [{'firstName': 'Dan', 'lastName': 'S', 'address': '', 'city': '', 'state': '', 'countryCode': 'US'}, {'firstName': 'Leo', 'lastName': 'K', 'countryCode': 'US'}, {'firstName': 'Ariel', 'lastName': 'H', 'countryCode': 'US'}, {'firstName': 'Mashka', 'countryCode': 'RO'}]}], 's ...
#                          ID           Name  Likes  Rating  Tips
# 0  5276d39a498eb1a5d90096e4  Sushi Katsuei    107     8.8    84
# ( 8 / 65 ) processed
# {'meta': {'code': 200, 'requestId': '60e40eecbd0a7d1e4c21f6e7'}, 'response': {'venue': {'id': '3fd66200f964a5208af11ee3', 'name': 'Yamato', 'contact': {'phone': '7188400099', 'formattedPhone': '(718) 840-0099'}, 'location': {'address': '163 7th Ave', 'crossStreet': 'at 1st St', 'lat': 40.67185629368959, 'lng': -73.97750393720924, 'labeledLatLngs': [{'label': 'display', 'lat': 40.67185629368959, 'lng': -73.97750393720924}, {'label': 'entrance', 'lat': 40.671924, 'lng': -73.977545}], 'postalCode': '11215', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['163 7th Ave (at 1st St)', 'Brooklyn, NY 11215', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/yamato/3fd66200f964a5208af11ee3', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1d2941735', 'name': 'Sushi Restaurant', 'pluralName': 'Sushi Restaurants', 'shortName': 'Sushi', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 30}, 'url': 'http://yamatonyc.com', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 45, 'groups': [{'type': 'others', 'count': 45, 'items': []}], 'summary': '45 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.0, 'ratingColor': '73CF42', 'ratingSignals': 55, 'delivery': {'id': '852617', 'url': 'https://www.seamless.com/menu/yamato-168-7th-ave-brooklyn/852617?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=852617', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/yamato/3fd66200f964a5208af11ee3/menu', 'mobileUrl': 'https://foursquare.com/v/3fd66200f964a5208af11ee3/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 36, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 36, 'items': [{'id': '4f42b36be4b0d98872567670', 'createdAt': 1329771371, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/mPaex8hdKPpqlVtQIIh3t2EUahgwEqU54LiaETpq398.jpg', 'width': 720, 'height': 537, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1071014400, 'tips': {'count': 30, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 30, 'items': [{'id': '5078c6c6e4b00eb860d738d2', 'createdAt': 1350092486, 'text': 'Sushi was filling, delicious and the service was great!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5078c6c6e4b00eb860d738d2', 'photo': {'id': '5078c6c9e4b07204c0a25488', 'createdAt': 1350092489, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/39232143_b5NqBsQhtfLO96h2NxYPtuujHRoAvtDWwE8BJLn2du8.jpg', 'width': 540, 'height': 720, 'visibility': 'public'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/39232143_b5NqBsQhtfLO96h2NxYPtuujHRoAvtDWwE8BJLn2du8.jpg', 'lang': 'en', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'firstName': 'Daniel', 'lastName': 'A', 'countryCode': 'CZ'}, {'firstName': 'InFOODxication', 'countryCode': 'US'}, {'firstName': 'Celi', 'lastName': 'A', 'countryC ...
#                          ID    Name  Likes  Rating  Tips
# 0  3fd66200f964a5208af11ee3  Yamato     45     8.0    30
# ( 9 / 65 ) processed
# {'meta': {'code': 200, 'requestId': '60e40eec1c8b5132e971c10f'}, 'response': {'venue': {'id': '4e3cadcb1f6e844231dbe017', 'name': 'Waza', 'contact': {'phone': '7183999292', 'formattedPhone': '(718) 399-9292'}, 'location': {'address': '485 Myrtle Ave', 'lat': 40.693487522158414, 'lng': -73.965735666986, 'labeledLatLngs': [{'label': 'display', 'lat': 40.693487522158414, 'lng': -73.965735666986}, {'label': 'entrance', 'lat': 40.693575, 'lng': -73.965731}], 'postalCode': '11205', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['485 Myrtle Ave', 'Brooklyn, NY 11205', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/waza/4e3cadcb1f6e844231dbe017', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 29}, 'url': 'http://wazasushi.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 41, 'groups': [{'type': 'others', 'count': 41, 'items': []}], 'summary': '41 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.5, 'ratingColor': 'FFC800', 'ratingSignals': 50, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/waza/4e3cadcb1f6e844231dbe017/menu', 'mobileUrl': 'https://foursquare.com/v/4e3cadcb1f6e844231dbe017/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 83, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 83, 'items': [{'id': '4e9dc94330f8b44979ae3ca3', 'createdAt': 1318963523, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/RM05DJWISNL52OACWSCQVSGTYDMUHPQWC5XM3N2ZASIBDX4V.jpg', 'width': 720, 'height': 537, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1312599499, 'tips': {'count': 29, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 29, 'items': [{'id': '5095d851e4b054dd34d1a2a7', 'createdAt': 1351997521, 'text': "I have never liked Sake until coming here-- and unbelievable spicy tuna rolls too! The waiter was also very funny. Can't recommend this place highly enough!", 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5095d851e4b054dd34d1a2a7', 'lang': 'en', 'likes': {'count': 2, 'groups': [{'type': 'others', 'count': 2, 'items': [{'firstName': 'Andrew', 'lastName': 'P', 'countryCode': 'US'}, {'firstName': 'Max', 'lastName': 'W', 'countryCode': 'US'}]}], 'summary': '2 likes'}, 'logView': True, 'agreeCount': 2, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Julia', 'countryCode': 'US'}}]}]}, 'shortUrl': 'http://4sq.com/qMfwEh', 'timeZone': 'America/New_York', 'listed': {'count': 33, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 33, 'items': [{'id': '51847fa5498e14c3527bbeea', 'name': 'Fort Greene+Clinton Hill+Bed-Stuy', 'description': 'That Brooklyn style.', 'type': 'others', 'user': {'firstName': 'Gennifer', 'lastName': 'D', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/genniferdelman/list/fort-greeneclinton-hillbedstuy', 'canonicalUrl': 'https://foursquare.com/genniferdelman/list/fort-greeneclinton-hillbedstuy', 'createdAt': 1367637925, 'updatedAt': 1378148883, 'photo': {'id': '5164801a8acae89489f35f56', 'createdAt': 1365540890, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/3107021_pdhUe69XvhrONTgudboxaGAokLPSUFWytt0VmMYYX9k.jpg', 'width': 380, 'height': 285,  ...
#                          ID  Name  Likes  Rating  Tips
# 0  4e3cadcb1f6e844231dbe017  Waza     41     6.5    29
# ( 10 / 65 ) processed
# {'meta': {'code': 200, 'requestId': '60e40eedf0348c0a14ac4a7a'}, 'response': {'venue': {'id': '5946d138e2da1964625ca9b2', 'name': 'Daigo Hand Roll Bar', 'contact': {}, 'location': {'address': '445 Albee Sq W', 'lat': 40.69125894731662, 'lng': -73.98260299755893, 'labeledLatLngs': [{'label': 'display', 'lat': 40.69125894731662, 'lng': -73.98260299755893}], 'postalCode': '11201', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['445 Albee Sq W', 'New York, NY 11201', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/daigo-hand-roll-bar/5946d138e2da1964625ca9b2', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 14}, 'url': 'https://www.daigohandrollbar.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 26, 'groups': [{'type': 'others', 'count': 26, 'items': []}], 'summary': '26 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.8, 'ratingColor': '73CF42', 'ratingSignals': 42, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://www.daigohandrollbar.com/menu/', 'mobileUrl': 'https://www.daigohandrollbar.com/menu/', 'externalUrl': 'https://www.daigohandrollbar.com/menu/'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 50, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 50, 'items': [{'id': '5d33b3411eef22000834b690', 'createdAt': 1563669313, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/19182072_BlwS-ncoCLxKtKC2cqttTEIBQFIKSqAP0K9QnO_5mZk.jpg', 'width': 1440, 'height': 1920, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1497813304, 'tips': {'count': 14, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 14, 'items': [{'id': '5d33969ab5191a0023d2df62', 'createdAt': 1563661978, 'text': 'Love everything about this place. Try the yellowtail with toasted jalapeño, salmon with avocado, and the Funiguchi gold or red can sake.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5d33969ab5191a0023d2df62', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'John', 'lastName': 'D', 'countryCode': 'US'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/2rFlmJK', 'timeZone': 'America/New_York', 'listed': {'count': 55, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 55, 'items': [{'id': '5a973a02610f0406e073aebf', 'name': 'Bars and Restaurants in NYC', 'description': '', 'type': 'others', 'user': {'firstName': 'Gabriela', 'lastName': 'L', 'countryCode': 'JP'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/40555956/list/bars-and-restaurants-in-nyc', 'canonicalUrl': 'https://foursquare.com/user/40555956/list/bars-and-restaurants-in-nyc', 'createdAt': 1519860226, 'updatedAt': 1576635055, 'photo': {'id': '5a8b66b65f68b90698ac72b3', 'createdAt': 1519085238, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/393532523_EUPahmwo2ZX64ojhmLMBYo7l-X_Isi7KQD5a6CCT9ao.jpg', 'width': 1440, 'height': 1920, 'visibility': 'public'}, 'followers': {'count': 1}, 'listItems': {'count': 105, 'items': [{'id': 'v5946d138e2da1964625ca9b2', 'createdAt': 1533151955}]}}, {'id': '5dd15a0cabe91100067a51a1', 'name': 'NY Favorites', 'description': 'The *best* places we’ve been to', 'type': 'others', 'user': {'firstName': 'Jeff', 'lastName': 'R', 'countryCode': 'US'}, 'editable': False, 'pu ...
#                          ID                 Name  Likes  Rating  Tips
# 0  5946d138e2da1964625ca9b2  Daigo Hand Roll Bar     26     8.8    14
# ( 11 / 65 ) processed
# ...
#                          ID       Name  Likes  Rating  Tips
# 0  446b2f7cf964a52058331fe3  Umi No Ie     96     8.4    46
# ( 47 / 65 ) processed
# {'meta': {'code': 200, 'requestId': '60e40ef7b37b8142fc93bb44'}, 'response': {'venue': {'id': '51e8ce40498ea1fb0180efb2', 'name': 'Izakaya MEW', 'contact': {'phone': '6463689384', 'formattedPhone': '(646) 368-9384', 'facebook': '141143689388266', 'facebookUsername': 'izakayamew', 'facebookName': 'Izakaya MEW'}, 'location': {'address': '53 W 35th St', 'crossStreet': 'btwn Avenue Of The Americas & 5th Ave', 'lat': 40.750145083699266, 'lng': -73.98639033818998, 'labeledLatLngs': [{'label': 'display', 'lat': 40.750145083699266, 'lng': -73.98639033818998}], 'postalCode': '10001', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['53 W 35th St (btwn Avenue Of The Americas & 5th Ave)', 'New York, NY 10001', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/izakaya-mew/51e8ce40498ea1fb0180efb2', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d11c941735', 'name': 'Sake Bar', 'pluralName': 'Sake Bars', 'shortName': 'Sake Bar', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sake_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 266}, 'url': 'http://mewnyc.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 1056, 'groups': [{'type': 'others', 'count': 1056, 'items': []}], 'summary': '1056 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.6, 'ratingColor': '73CF42', 'ratingSignals': 740, 'delivery': {'id': '604424', 'url': 'https://www.seamless.com/menu/izakaya-mew-53-w-35th-st-new-york/604424?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=604424', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/izakaya-mew/51e8ce40498ea1fb0180efb2/menu', 'mobileUrl': 'https://foursquare.com/v/51e8ce40498ea1fb0180efb2/device_menu', 'externalUrl': 'http://mewnyc.com/mew/'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 902, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 902, 'items': [{'id': '522526ff11d259bf6da52d37', 'createdAt': 1378166527, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/58683751_b5JTKK458pTlVjWAtO4yMtJhAX8ZFKE7TVPqNZF8xk0.jpg', 'width': 720, 'height': 960, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'serves lunch (cash only) & dinner (accepts credit cards) monday-friday\nMEWzik Sunday Jazz Nights on sundays', 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1374211648, 'tips': {'count': 266, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 266, 'items': [{'id': '527bd26911d20f41b678c9ef', 'createdAt': 1383846505, 'text': '$12 sashimi platter with 5 different types of sashimi and 2 pieces of each type! Also, the nabeyaki udon was perfect.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/527bd26911d20f41b678c9ef', 'lang': 'en', 'likes': {'count': 5, 'groups': [{'type': 'others', 'count': 5, 'items': [{'firstName': 'Aram', 'lastName': 'Z', 'countryCode': 'US'}, {'firstName': 'Harald', 'lastName': 'K', 'countryCode': 'US'}, {'firstName': 'Francis', 'lastName': 'L', 'countryCode': 'US'}]}], 'summary': '5 likes'}, 'logView': True, 'agreeCount': 5, 'disagreeCount': ...
#                          ID         Name  Likes  Rating  Tips
# 0  51e8ce40498ea1fb0180efb2  Izakaya MEW   1056     8.6   266
# ( 48 / 65 ) processed
# {'meta': {'code': 200, 'requestId': '60e40ef72f2b726e6e78ce3f'}, 'response': {'venue': {'id': '58b8ed467220e661ddf34104', 'name': 'KazuNori: The Original Hand Roll Bar', 'contact': {'phone': '3475945940', 'formattedPhone': '(347) 594-5940'}, 'location': {'address': '15 W 28th St', 'lat': 40.745156795853866, 'lng': -73.98821168140111, 'labeledLatLngs': [{'label': 'display', 'lat': 40.745156795853866, 'lng': -73.98821168140111}], 'postalCode': '10001', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['15 W 28th St', 'New York, NY 10001', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/kazunori-the-original-hand-roll-bar/58b8ed467220e661ddf34104', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1d2941735', 'name': 'Sushi Restaurant', 'pluralName': 'Sushi Restaurants', 'shortName': 'Sushi', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 127}, 'url': 'http://www.kazunorisushi.com', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 528, 'groups': [{'type': 'others', 'count': 528, 'items': []}], 'summary': '528 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.9, 'ratingColor': '73CF42', 'ratingSignals': 333, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/kazunori-the-original-hand-roll-bar/58b8ed467220e661ddf34104/menu', 'mobileUrl': 'https://foursquare.com/v/58b8ed467220e661ddf34104/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 224, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 224, 'items': [{'id': '58ed47d493eaf844b6cd356f', 'createdAt': 1491945428, 'source': {'name': 'Swarm for Android', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/17473019_iBMLG5fh08CutF0zPYM4G0IJiRihOfBj13d4nu6rQ_8.jpg', 'width': 1440, 'height': 810, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1488514374, 'tips': {'count': 127, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 127, 'items': [{'id': '58dbe9ef75e13713e08fbb73', 'createdAt': 1490807279, 'text': "Get the four or five roll combos. They are priced way better than ala carte. Also the line moves fast. Don't let it deter you.", 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/58dbe9ef75e13713e08fbb73', 'photo': {'id': '58dbe9ef75e13713e08fbb72', 'createdAt': 1490807279, 'source': {'name': 'Swarm for Android', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/18371_vWGHbtm1mM_EOauD2qvnbY2c4M2U91YUbwePTl-SuWY.jpg', 'width': 1440, 'height': 1080, 'visibility': 'friends'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/18371_vWGHbtm1mM_EOauD2qvnbY2c4M2U91YUbwePTl-SuWY.jpg', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': [{'firstName': 'Paul', 'lastName': 'V', 'countryCode': 'US'}]}], 'summary': '1 like'}, 'logView': True, 'agreeCount': 32, 'disagreeCount': 0, 'todo': {'count': 1}, 'user': {'firstName': 'Fred', 'lastName': 'W', 'countryCode': 'US'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/2mMltxb', 'timeZone': 'America/New_York', 'listed': {'count': 1226, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 1226, 'items': [{'id': '58b90c3c55d62233452cf06d', 'name': ...
#                          ID                                  Name  Likes  \
# 0  58b8ed467220e661ddf34104  KazuNori: The Original Hand Roll Bar    528
#
#    Rating  Tips
# 0     8.9   127
# ( 49 / 65 ) processed
# {'meta': {'code': 200, 'requestId': '60e40ef7bfbc96262c826867'}, 'response': {'venue': {'id': '57ab615d498eef084faa348b', 'name': 'Abiko Curry', 'contact': {'phone': '2126950888', 'formattedPhone': '(212) 695-0888', 'instagram': 'abikocurryny', 'facebook': '1413440995349237', 'facebookName': 'ABIKO CURRY'}, 'location': {'address': '2 W 32nd St', 'crossStreet': 'btwn Broadway & 5th Ave', 'lat': 40.74747461672708, 'lng': -73.98608184163182, 'labeledLatLngs': [{'label': 'display', 'lat': 40.74747461672708, 'lng': -73.98608184163182}], 'postalCode': '10001', 'cc': 'US', 'neighborhood': 'Koreatown', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['2 W 32nd St (btwn Broadway & 5th Ave)', 'New York, NY 10001', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/abiko-curry/57ab615d498eef084faa348b', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}, {'id': '55a59bace4b013909087cb30', 'name': 'Japanese Curry Restaurant', 'pluralName': 'Japanese Curry Restaurants', 'shortName': 'Japanese Curry', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 29}, 'url': 'https://www.abikocurryrestaurant.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 134, 'groups': [{'type': 'others', 'count': 134, 'items': []}], 'summary': '134 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.3, 'ratingColor': 'C5DE35', 'ratingSignals': 89, 'delivery': {'id': '1716886', 'url': 'https://www.seamless.com/menu/abiko-curry-2-w-32nd-street-new-york/1716886?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1716886', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 147, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 147, 'items': [{'id': '60e107e34bcd5b7c28afeff3', 'createdAt': 1625360355, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/531540700_MOWXvZueTKv2xhHsq7hVnLb1qn2Cx5ubPUxxMJNnLlQ.jpg', 'width': 1440, 'height': 1920, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1470849373, 'tips': {'count': 29, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 29, 'items': [{'id': '57ddaf60498ea711b5cc45ed', 'createdAt': 1474146144, 'text': 'Beware of the spiciness levels. if lvl 1 is 1x spicy (mild), then lvl 2 is 5x, lvl 3 is 15x, lvl 4 is 30x, lvl 5 is 60x. I prefer to get the lvl 1 spicy with some extra spicy powder on the side', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/57ddaf60498ea711b5cc45ed', 'lang': 'en', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'firstName': 'Domenick', 'lastName': 'W', 'countryCode': 'US'}, {'firstName': 'Jason', 'lastName': 'A', 'countryCode': 'US'}]}], 'summary': '3 likes'}, 'logView': True, 'editedAt': 1503608508, 'agreeCount': 14, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Danny', 'lastName': 'C', 'countryCode': 'US'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/2b44xwe', 'timeZone': 'America/New_York', 'listed': {'count': 83, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 83, 'items': [{'id': '5b30458497 ...
#                          ID         Name  Likes  Rating  Tips
# 0  57ab615d498eef084faa348b  Abiko Curry    134     7.3    29
# ( 50 / 65 ) processed
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '60e40ef8121e2a2b6023ef41'}, 'response': {}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-6ed04af23668> in <module>
#       5     Borough,Neighborhood,ID,Name=row
#       6     try:
# ----> 7         venue_details=get_venue_details(ID)
#       8         print(venue_details)
#       9         id,name,likes,rating,tips=venue_details.values.tolist()[0]
#
# <ipython-input-3-e5a838665531> in get_venue_details(venue_id)
#      49     results = requests.get(url).json()
#      50     print(results)
# ---> 51     venue_data=results['response']['venue']
#      52     venue_details=[]
#      53     try:
#
# KeyError: 'venue'

# %%
japanese_rest_stats_ny.to_csv('japanese_rest_stats_ny_csv.csv') # As I move through this project I continue to save data to a .csv file
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-15-283d1f99292c> in <module>
# ----> 1 japanese_rest_stats_ny.to_csv('japanese_rest_stats_ny_csv.csv') # As I move through this project I continue to save data to a .csv file
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3178             Make the row labels bold in the output.
#    3179         column_format : str, optional
# -> 3180             The columns format as specified in `LaTeX table format
#    3181             <https://en.wikibooks.org/wiki/LaTeX/Tables>`__ e.g. 'rcl' for 3
#    3182             columns. By default, 'l' will be used for all columns except
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/formats/csvs.py in <module>
#      19
#      20 from pandas._libs import writers as libwriters
# ---> 21 from pandas._typing import (
#      22     CompressionOptions,
#      23     FilePathOrBuffer,
#
# ImportError: cannot import name 'CompressionOptions' from 'pandas._typing' (/opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/_typing.py)

# %%
japanese_rest_stats_ny.shape
# Out:
# (50, 7)

# %%
japanese_rest_stats_ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Borough       50 non-null     object
#  1   Neighborhood  50 non-null     object
#  2   ID            50 non-null     object
#  3   Name          50 non-null     object
#  4   Likes         50 non-null     object
#  5   Rating        50 non-null     float64
#  6   Tips          50 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 2.9+ KB

# %%
japanese_rest_stats_ny['Likes'] = japanese_rest_stats_ny['Likes'].astype('float64')
japanese_rest_stats_ny['Tips'] = japanese_rest_stats_ny['Tips'].astype('float64')
japanese_rest_stats_ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Borough       50 non-null     object
#  1   Neighborhood  50 non-null     object
#  2   ID            50 non-null     object
#  3   Name          50 non-null     object
#  4   Likes         50 non-null     float64
#  5   Rating        50 non-null     float64
#  6   Tips          50 non-null     float64
# dtypes: float64(3), object(4)
# memory usage: 2.9+ KB

# %%
japanese_rest_stats_ny.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/frame.py in _repr_html_(self)
#     732             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#     733             # expected "Union[Union[Union[ExtensionArray, ndarray],
# --> 734             # Index, Series], Sequence[Any]]"
#     735             index = ensure_index(index)  # type: ignore[arg-type]
#     736             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/formats/format.py in to_html(self, buf, encoding, classes, notebook, border)
#     980         string = latex_formatter.to_string()
#     981         return save_to_buffer(string, buf=buf, encoding=encoding)
# --> 982
#     983     def to_html(
#     984         self,
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/formats/html.py in __init__(self, formatter, classes, border, table_id, render_links)
#      66         self.col_space = {
#      67             column: f"{value}px" if isinstance(value, int) else value
# ---> 68             for column, value in self.fmt.col_space.items()
#      69         }
#      70
#
# AttributeError: 'NoneType' object has no attribute 'items'
#              Likes     Rating        Tips
# count    50.000000  50.000000   50.000000
# mean    130.280000   6.728000   48.560000
# std     218.975075   3.029989   75.130678
# min       0.000000   0.000000    0.000000
# 25%      13.500000   7.225000    6.000000
# 50%      38.000000   7.850000   15.000000
# 75%     104.250000   8.400000   59.500000
# max    1056.000000   9.300000  352.000000

# %%
# Resturant with maximum Likes
japanese_rest_stats_ny.iloc[japanese_rest_stats_ny['Likes'].idxmax()]
# Out:
# Borough                        Manhattan
# Neighborhood               Midtown South
# ID              51e8ce40498ea1fb0180efb2
# Name                         Izakaya MEW
# Likes                               1056
# Rating                               8.6
# Tips                                 266
# Name: 47, dtype: object

# %%
# Resturant with maximum Ratings
japanese_rest_stats_ny.iloc[japanese_rest_stats_ny['Rating'].idxmax()]
# Out:
# Borough                        Manhattan
# Neighborhood                East Village
# ID              5b3805910dd31f002409405a
# Name                          Suki Curry
# Likes                                 23
# Rating                               9.3
# Tips                                  15
# Name: 28, dtype: object

# %%
# Resturant with maximum Tips
japanese_rest_stats_ny.iloc[japanese_rest_stats_ny['Tips'].idxmax()]
# Out:
# Borough                        Manhattan
# Neighborhood                     Chelsea
# ID              454f7cc4f964a520dc3c1fe3
# Name                            Morimoto
# Likes                                791
# Rating                               8.5
# Tips                                 352
# Name: 25, dtype: object

# %% [markdown]
# Identify and visualize neighborhood with the maximum average rating of restaurants

# %%
ny_neighborhood_stats=japanese_rest_stats_ny.groupby('Neighborhood',as_index=False).mean()[['Neighborhood','Rating']]
ny_neighborhood_stats.columns=['Neighborhood','Average Rating']
ny_neighborhood_stats.sort_values(['Average Rating'],ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/frame.py in _repr_html_(self)
#     732             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#     733             # expected "Union[Union[Union[ExtensionArray, ndarray],
# --> 734             # Index, Series], Sequence[Any]]"
#     735             index = ensure_index(index)  # type: ignore[arg-type]
#     736             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/formats/format.py in to_html(self, buf, encoding, classes, notebook, border)
#     980         string = latex_formatter.to_string()
#     981         return save_to_buffer(string, buf=buf, encoding=encoding)
# --> 982
#     983     def to_html(
#     984         self,
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/formats/html.py in __init__(self, formatter, classes, border, table_id, render_links)
#      66         self.col_space = {
#      67             column: f"{value}px" if isinstance(value, int) else value
# ---> 68             for column, value in self.fmt.col_space.items()
#      69         }
#      70
#
# AttributeError: 'NoneType' object has no attribute 'items'
#        Neighborhood  Average Rating
# 10     East Village            9.25
# 8       Cobble Hill            8.80
# 9          Downtown            8.80
# 31             Soho            8.70
# 33  Upper East Side            8.60
# 26       North Side            8.60
# 6           Chelsea            8.50
# 19       Lenox Hill            8.40
# 27       Park Slope            8.40
# 25             Noho            8.40

# %% [markdown]
# Top neighborhoods with the highest average ratings of Japanese restaurants

# %%
ny_borough_stats=japanese_rest_stats_ny.groupby('Borough',as_index=False).mean()[['Borough','Rating']]
ny_borough_stats.columns=['Borough','Average Rating']
ny_borough_stats.sort_values(['Average Rating'],ascending=False).head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/frame.py in _repr_html_(self)
#     732             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#     733             # expected "Union[Union[Union[ExtensionArray, ndarray],
# --> 734             # Index, Series], Sequence[Any]]"
#     735             index = ensure_index(index)  # type: ignore[arg-type]
#     736             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/formats/format.py in to_html(self, buf, encoding, classes, notebook, border)
#     980         string = latex_formatter.to_string()
#     981         return save_to_buffer(string, buf=buf, encoding=encoding)
# --> 982
#     983     def to_html(
#     984         self,
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/formats/html.py in __init__(self, formatter, classes, border, table_id, render_links)
#      66         self.col_space = {
#      67             column: f"{value}px" if isinstance(value, int) else value
# ---> 68             for column, value in self.fmt.col_space.items()
#      69         }
#      70
#
# AttributeError: 'NoneType' object has no attribute 'items'
#          Borough  Average Rating
# 1      Manhattan            8.26
# 0       Brooklyn            7.40
# 3  Staten Island            4.40
# 2         Queens            3.82

# %% [markdown]
# Visualize the results

# %%
plt.figure(figsize=(9,5), dpi = 100)
plt.title('Average rating of Japanese Restaurants for each Borough')
plt.xlabel('Borough', fontsize = 15)
plt.ylabel('Average Rating', fontsize=15)
japanese_rest_stats_ny.groupby('Borough').mean()['Rating'].plot(kind='bar', color=clr)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-25-e2f715a98d94> in <module>
#       3 plt.xlabel('Borough', fontsize = 15)
#       4 plt.ylabel('Average Rating', fontsize=15)
# ----> 5 japanese_rest_stats_ny.groupby('Borough').mean()['Rating'].plot(kind='bar', color=clr)
#       6 plt.legend()
#       7 plt.show()
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     765     Returns
#     766     -------
# --> 767     :class:`matplotlib.axes.Axes` or numpy.ndarray of them
#     768         If the backend is not the default matplotlib one, the return value
#     769         will be the object returned by the backend.
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1667             chosen in a way that the hexagons are approximately regular.
#    1668             Alternatively, gridsize can be a tuple with two elements
# -> 1669             specifying the number of hexagons in the x-direction and the
#    1670             y-direction.
#    1671         **kwargs
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.

# %% [markdown]
# Neighborhoods with average rating greater or equal 8.0 to visualize on a map

# %%
ny_neighborhood_stats=ny_neighborhood_stats[ny_neighborhood_stats['Average Rating']>=8.0]
ny_neighborhood_stats
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/frame.py in _repr_html_(self)
#     732             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#     733             # expected "Union[Union[Union[ExtensionArray, ndarray],
# --> 734             # Index, Series], Sequence[Any]]"
#     735             index = ensure_index(index)  # type: ignore[arg-type]
#     736             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/formats/format.py in to_html(self, buf, encoding, classes, notebook, border)
#     980         string = latex_formatter.to_string()
#     981         return save_to_buffer(string, buf=buf, encoding=encoding)
# --> 982
#     983     def to_html(
#     984         self,
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/formats/html.py in __init__(self, formatter, classes, border, table_id, render_links)
#      66         self.col_space = {
#      67             column: f"{value}px" if isinstance(value, int) else value
# ---> 68             for column, value in self.fmt.col_space.items()
#      69         }
#      70
#
# AttributeError: 'NoneType' object has no attribute 'items'
#          Neighborhood  Average Rating
# 1         Boerum Hill        8.400000
# 6             Chelsea        8.500000
# 8         Cobble Hill        8.800000
# 9            Downtown        8.800000
# 10       East Village        9.250000
# 12           Grasmere        8.000000
# 14  Greenwich Village        8.200000
# 18         Kensington        8.100000
# 19         Lenox Hill        8.400000
# 20         Lindenwood        8.400000
# 23      Midtown South        8.266667
# 25               Noho        8.400000
# 26         North Side        8.600000
# 27         Park Slope        8.400000
# 31               Soho        8.700000
# 33    Upper East Side        8.600000
# 38          Yorkville        8.100000

# %% [markdown]
# Join the Dataset to original New York data to get longitude and latitude

# %%
ny_neighborhood_stats=pd.merge(ny_neighborhood_stats,ny_data, on='Neighborhood')
ny_neighborhood_stats=ny_neighborhood_stats[['Borough','Neighborhood','Latitude','Longitude','Average Rating']]
ny_neighborhood_stats
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/frame.py in _repr_html_(self)
#     732             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#     733             # expected "Union[Union[Union[ExtensionArray, ndarray],
# --> 734             # Index, Series], Sequence[Any]]"
#     735             index = ensure_index(index)  # type: ignore[arg-type]
#     736             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/formats/format.py in to_html(self, buf, encoding, classes, notebook, border)
#     980         string = latex_formatter.to_string()
#     981         return save_to_buffer(string, buf=buf, encoding=encoding)
# --> 982
#     983     def to_html(
#     984         self,
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/formats/html.py in __init__(self, formatter, classes, border, table_id, render_links)
#      66         self.col_space = {
#      67             column: f"{value}px" if isinstance(value, int) else value
# ---> 68             for column, value in self.fmt.col_space.items()
#      69         }
#      70
#
# AttributeError: 'NoneType' object has no attribute 'items'
#           Borough       Neighborhood   Latitude  Longitude  Average Rating
# 0        Brooklyn        Boerum Hill  40.685683 -73.983748        8.400000
# 1       Manhattan            Chelsea  40.744035 -74.003116        8.500000
# 2   Staten Island            Chelsea  40.594726 -74.189560        8.500000
# 3        Brooklyn        Cobble Hill  40.687920 -73.998561        8.800000
# 4        Brooklyn           Downtown  40.690844 -73.983463        8.800000
# 5       Manhattan       East Village  40.727847 -73.982226        9.250000
# 6   Staten Island           Grasmere  40.598268 -74.076674        8.000000
# 7       Manhattan  Greenwich Village  40.726933 -73.999914        8.200000
# 8        Brooklyn         Kensington  40.642382 -73.980421        8.100000
# 9       Manhattan         Lenox Hill  40.768113 -73.958860        8.400000
# 10         Queens         Lindenwood  40.663918 -73.849638        8.400000
# 11      Manhattan      Midtown South  40.748510 -73.988713        8.266667
# 12      Manhattan               Noho  40.723259 -73.988434        8.400000
# 13       Brooklyn         North Side  40.714823 -73.958809        8.600000
# 14       Brooklyn         Park Slope  40.672321 -73.977050        8.400000
# 15      Manhattan               Soho  40.722184 -74.000657        8.700000
# 16      Manhattan    Upper East Side  40.775639 -73.960508        8.600000
# 17      Manhattan          Yorkville  40.775930 -73.947118        8.100000

# %% [markdown]
# Showing the data on a map

# %%
# create map and display it
ny_map = folium.Map(location=geo_location('New York'), zoom_start=12)
# instantiate a feature group for the ratings in the dataframe
rating = folium.map.FeatureGroup()

# loop through the ratings and add each to the neighborhood feature group
for lat, lng, in ny_neighborhood_stats[['Latitude','Longitude']].values:
    rating.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# %% [markdown]
# Adding a new field to dataframe for labeling purpose

# %%
ny_neighborhood_stats['Label']=ny_neighborhood_stats['Neighborhood']+', '+ny_neighborhood_stats['Borough']+'('+ny_neighborhood_stats['Average Rating'].map(str)+')'
# add pop-up text to each marker on the map
for lat, lng, label in ny_neighborhood_stats[['Latitude','Longitude','Label']].values:
    folium.Marker([lat, lng], popup=label).add_to(ny_map)        
# add ratings to map
ny_map.add_child(rating)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-29-1ff30fc7b4b6> in <module>
# ----> 1 ny_neighborhood_stats['Label']=ny_neighborhood_stats['Neighborhood']+', '+ny_neighborhood_stats['Borough']+'('+ny_neighborhood_stats['Average Rating'].map(str)+')'
#       2 # add pop-up text to each marker on the map
#       3 for lat, lng, label in ny_neighborhood_stats[['Latitude','Longitude','Label']].values:
#       4     folium.Marker([lat, lng], popup=label).add_to(ny_map)
#       5 # add ratings to map
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      62                 if isinstance(self, cls):
#      63                     break
# ---> 64                 if isinstance(other, cls):
#      65                     return NotImplemented
#      66
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(left, right)
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in arithmetic_op(left, right, op, str_rep)
#     195     right : object
#     196         Cannot be a DataFrame or Index.  Series is *not* excluded.
# --> 197     op : {operator.add, operator.sub, ...}
#     198         Or one of the reversed variants from roperator.
#     199
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     144     Parameters
#     145     ----------
# --> 146     left : np.ndarray
#     147     right : np.ndarray or scalar
#     148     is_cmp : bool, default False
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/computation/expressions.py in <module>
#      15 from pandas._config import get_option
#      16
# ---> 17 from pandas._typing import FuncType
#      18
#      19 from pandas.core.computation.check import NUMEXPR_INSTALLED
#
# ImportError: cannot import name 'FuncType' from 'pandas._typing' (/opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/_typing.py)
